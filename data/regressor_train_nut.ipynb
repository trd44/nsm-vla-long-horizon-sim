# %%
import zipfile
import pickle
import os
import cv2
import numpy as np

def load_from_zip(zip_path):
    """
    Load pickled data stored inside a .zip file created by TrajectoryRecorder.save_buffer.
    
    Args:
        zip_path (str): Path to the .zip file.
    
    Returns:
        object: The Python object that was originally pickled (list, dict, etc.).
    """
    with zipfile.ZipFile(zip_path, 'r') as zip_file:
        with zip_file.open('data.pkl', 'r') as file:
            data = pickle.load(file)
    return data

def transform_to_list_of_images_dict(data):
    # Takes a list of type [act1, obs1, act2, obs2, ...] with obs being a dict "image_0", "image_1", "objects_pos"
    # Outputs a list of dict [obs1, obs2, ...] with obs being a dict {"_agentview":..., "wrist_image":...} 
    # image_0 is agentview, image_1 is wrist view
    images_list = []
    for episode in data:
        obs_list = []
        traj = episode[0]
        for i in range(1, len(traj), 2):
            obs = traj[i]
            if obs is None:
                continue
            img_dict = {"objects_pos": obs["objects_pos"].copy()}  # Copy the objects_pos dict
            if "image_0" in obs:
                image = obs["image_0"]
                image = cv2.flip(image.reshape(256, 256, 3), 0)
                # Change the image to BGR
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                img_dict["agentview"] = image
            if "image_1" in obs:
                image = obs["image_1"]
                image = cv2.flip(image.reshape(256, 256, 3), 0)
                # Change the image to BGR
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                img_dict["wrist_image"] = image
            obs_list.append(img_dict)
        images_list.append(obs_list)
    return images_list

# %%
# yolo imports
from ultralytics import YOLO
from roboflow import Roboflow
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2
import joblib
import pandas as pd

# %%
def get_episode_preds_and_ground_truth(episode, yolo_model):
    info_list = []
    for obs_step in episode:
        info = {}
        if "agentview" not in obs_step or "wrist_image" not in obs_step:
            continue
        agentview = obs_step["agentview"]
        wrist_image = obs_step["wrist_image"]
        # Get the predictions
        agentview_results = yolo_model(agentview, verbose=False)[0]
        wrist_results = yolo_model(wrist_image, verbose=False)[0]
        #print(obs_step.keys())
        objects_info = obs_step["objects_pos"]  # dict with object names as keys and positions as values
        for pred in agentview_results.boxes:
            cls_id = int(pred.cls)
            cls = yolo_model.names[cls_id]
            # Remove the "_" from the class name
            cls = cls.replace("_", "")
            x, y, w, h = pred.xywhn.tolist()[0]
            conf = pred.conf
            # Convert normalized coordinates to pixel coordinates
            x = int(x * agentview.shape[1])
            y = int(y * agentview.shape[0])
            w = int(w * agentview.shape[1])
            h = int(h * agentview.shape[0])

            # Convert to pixel coordinates
            x1, y1 = int(x - w / 2), int(y - h / 2)
            x2, y2 = int(x + w / 2), int(y + h / 2)

            #print(cls, objects_info.keys())
            # Get the ground truth position of the object
            if cls in objects_info:
                ground_truth_xyz = objects_info[cls]
                ee_pos = objects_info["gripper"]

                found_match = False
                for pred in wrist_results.boxes:
                    cls_id2 = int(pred.cls)
                    if cls_id2 == cls_id:
                            found_match = True
                            x_cam2, y_cam2, w_cam2, h_cam2 = pred.xywhn.tolist()[0]
                            conf_cam2 = pred.conf
                            # Convert normalized coordinates to pixel coordinates
                            x_cam2 = int(x_cam2 * wrist_image.shape[1])
                            y_cam2 = int(y_cam2 * wrist_image.shape[0])
                            w_cam2 = int(w_cam2 * wrist_image.shape[1])
                            h_cam2 = int(h_cam2 * wrist_image.shape[0])

                            info = {
                                "px_cam1": x,
                                "py_cam1": y,
                                "w_cam1": w,
                                "h_cam1": h,
                                "conf_cam1": float(conf),
                                "cls": cls,
                                "px_cam2": x_cam2,
                                "py_cam2": y_cam2,
                                "w_cam2": w_cam2,
                                "h_cam2": h_cam2,
                                "conf_cam2": float(conf_cam2),
                                "ee_x": ee_pos[0] if ee_pos is not None else None,
                                "ee_y": ee_pos[1] if ee_pos is not None else None,
                                "ee_z": ee_pos[2] if ee_pos is not None else None,
                                "world_x": ground_truth_xyz[0],
                                "world_y": ground_truth_xyz[1],
                                "world_z": ground_truth_xyz[2],
                            }
                if not found_match:
                    x_cam2, y_cam2, w_cam2, h_cam2, conf_cam2 = 0, 0, 0, 0, 0
                    info ={
                        "px_cam1": x,
                        "py_cam1": y,
                        "w_cam1": w,
                        "h_cam1": h,
                        "conf_cam1": float(conf),
                        "cls": cls,
                        "px_cam2": 0,
                        "py_cam2": 0,
                        "w_cam2": 0,
                        "h_cam2": 0,
                        "conf_cam2": 0,
                        "ee_x": ee_pos[0] if ee_pos is not None else None,
                        "ee_y": ee_pos[1] if ee_pos is not None else None,
                        "ee_z": ee_pos[2] if ee_pos is not None else None,
                        "world_x": ground_truth_xyz[0],
                        "world_y": ground_truth_xyz[1],
                        "world_z": ground_truth_xyz[2],
                        }
            info_list.append(info)
    return info_list

# %%
# Create a df that, for each label in the yolo model, gets the world_pos of the corresponding object as well as the ee_pos
df_list = []
# find all zip files in a directory
yolo_model = YOLO("../PDDL/yolo_nutassembly.pt")
data_dir = "/home/lorangpi/CyclicLxM/data/NutAssembly_seed_0/train_yolo/traces"
zip_files = [f for f in os.listdir(data_dir) if f.endswith('reach_place.zip')]
for zip_file in zip_files:
    zip_path = os.path.join(data_dir, zip_file)
    zip_name = os.path.splitext(zip_file)[0]
    videos_dir = os.path.join(data_dir, zip_name, 'videos')
    os.makedirs(videos_dir, exist_ok=True)
    yolo_data = load_from_zip(zip_path)
    h264_videos_dir = os.path.join(videos_dir, 'h264')
    os.makedirs(h264_videos_dir, exist_ok=True)
    print(f"Processing {zip_file} with {len(yolo_data)} entries")
    yolo_data = transform_to_list_of_images_dict(yolo_data)
    for episode_id, episode in enumerate(yolo_data):
        print(f"expisode {episode_id} with {len(episode)} steps")
        ep_info = get_episode_preds_and_ground_truth(episode, yolo_model)
        if len(ep_info) > 0:
            df_list.extend(ep_info)
        # if episode_id >= 10:
        #     break
# Out:
# Processing pick.zip with 27 entries
# expisode 0 with 150 steps
# expisode 1 with 153 steps
# expisode 2 with 150 steps
# expisode 3 with 155 steps
# expisode 4 with 156 steps
# expisode 5 with 150 steps
# expisode 6 with 149 steps
# expisode 7 with 151 steps
# expisode 8 with 151 steps
# expisode 9 with 151 steps
# expisode 10 with 151 steps
# Processing reach_pick.zip with 27 entries
# expisode 0 with 181 steps
# expisode 1 with 182 steps
# expisode 2 with 183 steps
# expisode 3 with 176 steps
# expisode 4 with 179 steps
# expisode 5 with 184 steps
# expisode 6 with 194 steps
# expisode 7 with 179 steps
# expisode 8 with 192 steps
# expisode 9 with 185 steps
# expisode 10 with 189 steps
# Processing reach_place.zip with 27 entries
# expisode 0 with 146 steps
# expisode 1 with 151 steps
# expisode 2 with 155 steps
# expisode 3 with 150 steps
# expisode 4 with 147 steps
# expisode 5 with 151 steps
# expisode 6 with 163 steps
# expisode 7 with 150 steps
# expisode 8 with 159 steps
# expisode 9 with 157 steps
# expisode 10 with 187 steps
# Processing place.zip with 27 entries
# expisode 0 with 84 steps
# expisode 1 with 82 steps
# expisode 2 with 81 steps
# expisode 3 with 86 steps
# expisode 4 with 87 steps
# expisode 5 with 83 steps
# expisode 6 with 84 steps
# expisode 7 with 85 steps
# expisode 8 with 84 steps
# expisode 9 with 83 steps
# expisode 10 with 84 steps

# %%
df_list
# Out:
# [{'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9185290336608887,
#   'cls': 'roundnut',
#   'px_cam2': 151,
#   'py_cam2': 152,
#   'w_cam2': 46,
#   'h_cam2': 57,
#   'conf_cam2': 0.9521005153656006,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157389402389526,
#   'cls': 'squarenut',
#   'px_cam2': 44,
#   'py_cam2': 146,
#   'w_cam2': 58,
#   'h_cam2': 49,
#   'conf_cam2': 0.9357568025588989,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9185612201690674,
#   'cls': 'roundnut',
#   'px_cam2': 151,
#   'py_cam2': 151,
#   'w_cam2': 46,
#   'h_cam2': 57,
#   'conf_cam2': 0.9539939165115356,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157389998435974,
#   'cls': 'squarenut',
#   'px_cam2': 44,
#   'py_cam2': 146,
#   'w_cam2': 58,
#   'h_cam2': 48,
#   'conf_cam2': 0.935890257358551,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9185804724693298,
#   'cls': 'roundnut',
#   'px_cam2': 151,
#   'py_cam2': 152,
#   'w_cam2': 47,
#   'h_cam2': 57,
#   'conf_cam2': 0.9540072679519653,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157333970069885,
#   'cls': 'squarenut',
#   'px_cam2': 44,
#   'py_cam2': 146,
#   'w_cam2': 58,
#   'h_cam2': 49,
#   'conf_cam2': 0.9351533651351929,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9186251163482666,
#   'cls': 'roundnut',
#   'px_cam2': 151,
#   'py_cam2': 152,
#   'w_cam2': 46,
#   'h_cam2': 57,
#   'conf_cam2': 0.9536592364311218,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157243967056274,
#   'cls': 'squarenut',
#   'px_cam2': 44,
#   'py_cam2': 146,
#   'w_cam2': 58,
#   'h_cam2': 49,
#   'conf_cam2': 0.9348198771476746,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9186872839927673,
#   'cls': 'roundnut',
#   'px_cam2': 152,
#   'py_cam2': 152,
#   'w_cam2': 47,
#   'h_cam2': 58,
#   'conf_cam2': 0.9570722579956055,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157299995422363,
#   'cls': 'squarenut',
#   'px_cam2': 43,
#   'py_cam2': 146,
#   'w_cam2': 58,
#   'h_cam2': 49,
#   'conf_cam2': 0.9392654895782471,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9186728000640869,
#   'cls': 'roundnut',
#   'px_cam2': 152,
#   'py_cam2': 152,
#   'w_cam2': 48,
#   'h_cam2': 58,
#   'conf_cam2': 0.9569164514541626,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157180190086365,
#   'cls': 'squarenut',
#   'px_cam2': 42,
#   'py_cam2': 147,
#   'w_cam2': 60,
#   'h_cam2': 51,
#   'conf_cam2': 0.93882155418396,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9186002612113953,
#   'cls': 'roundnut',
#   'px_cam2': 153,
#   'py_cam2': 152,
#   'w_cam2': 49,
#   'h_cam2': 60,
#   'conf_cam2': 0.9589065909385681,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157063961029053,
#   'cls': 'squarenut',
#   'px_cam2': 40,
#   'py_cam2': 147,
#   'w_cam2': 61,
#   'h_cam2': 51,
#   'conf_cam2': 0.9409005045890808,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9186257123947144,
#   'cls': 'roundnut',
#   'px_cam2': 153,
#   'py_cam2': 153,
#   'w_cam2': 50,
#   'h_cam2': 60,
#   'conf_cam2': 0.9599360823631287,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157091379165649,
#   'cls': 'squarenut',
#   'px_cam2': 38,
#   'py_cam2': 148,
#   'w_cam2': 62,
#   'h_cam2': 52,
#   'conf_cam2': 0.9422296285629272,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9184795618057251,
#   'cls': 'roundnut',
#   'px_cam2': 154,
#   'py_cam2': 154,
#   'w_cam2': 51,
#   'h_cam2': 61,
#   'conf_cam2': 0.9599353075027466,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915719747543335,
#   'cls': 'squarenut',
#   'px_cam2': 37,
#   'py_cam2': 149,
#   'w_cam2': 64,
#   'h_cam2': 53,
#   'conf_cam2': 0.9391456842422485,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9183920621871948,
#   'cls': 'roundnut',
#   'px_cam2': 154,
#   'py_cam2': 155,
#   'w_cam2': 52,
#   'h_cam2': 63,
#   'conf_cam2': 0.9636857509613037,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157795310020447,
#   'cls': 'squarenut',
#   'px_cam2': 35,
#   'py_cam2': 150,
#   'w_cam2': 65,
#   'h_cam2': 55,
#   'conf_cam2': 0.9402987360954285,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9182220697402954,
#   'cls': 'roundnut',
#   'px_cam2': 155,
#   'py_cam2': 156,
#   'w_cam2': 53,
#   'h_cam2': 65,
#   'conf_cam2': 0.9635879993438721,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157937169075012,
#   'cls': 'squarenut',
#   'px_cam2': 34,
#   'py_cam2': 151,
#   'w_cam2': 66,
#   'h_cam2': 56,
#   'conf_cam2': 0.944127082824707,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9181811809539795,
#   'cls': 'roundnut',
#   'px_cam2': 155,
#   'py_cam2': 157,
#   'w_cam2': 54,
#   'h_cam2': 65,
#   'conf_cam2': 0.9590537548065186,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158477187156677,
#   'cls': 'squarenut',
#   'px_cam2': 33,
#   'py_cam2': 151,
#   'w_cam2': 66,
#   'h_cam2': 56,
#   'conf_cam2': 0.9442922472953796,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9182376861572266,
#   'cls': 'roundnut',
#   'px_cam2': 156,
#   'py_cam2': 158,
#   'w_cam2': 56,
#   'h_cam2': 67,
#   'conf_cam2': 0.9505162239074707,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158961772918701,
#   'cls': 'squarenut',
#   'px_cam2': 32,
#   'py_cam2': 152,
#   'w_cam2': 64,
#   'h_cam2': 57,
#   'conf_cam2': 0.9440878033638,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.918332040309906,
#   'cls': 'roundnut',
#   'px_cam2': 156,
#   'py_cam2': 159,
#   'w_cam2': 56,
#   'h_cam2': 67,
#   'conf_cam2': 0.9496162533760071,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915878415107727,
#   'cls': 'squarenut',
#   'px_cam2': 31,
#   'py_cam2': 153,
#   'w_cam2': 62,
#   'h_cam2': 58,
#   'conf_cam2': 0.9446974396705627,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.918562650680542,
#   'cls': 'roundnut',
#   'px_cam2': 157,
#   'py_cam2': 160,
#   'w_cam2': 58,
#   'h_cam2': 68,
#   'conf_cam2': 0.9525192975997925,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158869981765747,
#   'cls': 'squarenut',
#   'px_cam2': 30,
#   'py_cam2': 154,
#   'w_cam2': 61,
#   'h_cam2': 60,
#   'conf_cam2': 0.9445425271987915,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9183604121208191,
#   'cls': 'roundnut',
#   'px_cam2': 158,
#   'py_cam2': 163,
#   'w_cam2': 60,
#   'h_cam2': 73,
#   'conf_cam2': 0.9421765804290771,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158033728599548,
#   'cls': 'squarenut',
#   'px_cam2': 29,
#   'py_cam2': 155,
#   'w_cam2': 59,
#   'h_cam2': 61,
#   'conf_cam2': 0.9477133750915527,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9184138774871826,
#   'cls': 'roundnut',
#   'px_cam2': 158,
#   'py_cam2': 163,
#   'w_cam2': 62,
#   'h_cam2': 73,
#   'conf_cam2': 0.9372684359550476,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915999174118042,
#   'cls': 'squarenut',
#   'px_cam2': 29,
#   'py_cam2': 155,
#   'w_cam2': 58,
#   'h_cam2': 61,
#   'conf_cam2': 0.9433705806732178,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9181441068649292,
#   'cls': 'roundnut',
#   'px_cam2': 159,
#   'py_cam2': 164,
#   'w_cam2': 62,
#   'h_cam2': 74,
#   'conf_cam2': 0.9431560039520264,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9160600900650024,
#   'cls': 'squarenut',
#   'px_cam2': 28,
#   'py_cam2': 156,
#   'w_cam2': 57,
#   'h_cam2': 63,
#   'conf_cam2': 0.9363203048706055,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9180192947387695,
#   'cls': 'roundnut',
#   'px_cam2': 160,
#   'py_cam2': 164,
#   'w_cam2': 64,
#   'h_cam2': 75,
#   'conf_cam2': 0.9504334330558777,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915860116481781,
#   'cls': 'squarenut',
#   'px_cam2': 27,
#   'py_cam2': 158,
#   'w_cam2': 55,
#   'h_cam2': 65,
#   'conf_cam2': 0.9180648326873779,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9181590676307678,
#   'cls': 'roundnut',
#   'px_cam2': 161,
#   'py_cam2': 165,
#   'w_cam2': 66,
#   'h_cam2': 76,
#   'conf_cam2': 0.9420369267463684,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158526062965393,
#   'cls': 'squarenut',
#   'px_cam2': 26,
#   'py_cam2': 158,
#   'w_cam2': 53,
#   'h_cam2': 65,
#   'conf_cam2': 0.9097081422805786,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.917809009552002,
#   'cls': 'roundnut',
#   'px_cam2': 162,
#   'py_cam2': 165,
#   'w_cam2': 67,
#   'h_cam2': 77,
#   'conf_cam2': 0.9275741577148438,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9159358143806458,
#   'cls': 'squarenut',
#   'px_cam2': 25,
#   'py_cam2': 158,
#   'w_cam2': 50,
#   'h_cam2': 65,
#   'conf_cam2': 0.9144058227539062,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9174883365631104,
#   'cls': 'roundnut',
#   'px_cam2': 164,
#   'py_cam2': 166,
#   'w_cam2': 71,
#   'h_cam2': 78,
#   'conf_cam2': 0.9053948521614075,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9161908626556396,
#   'cls': 'squarenut',
#   'px_cam2': 24,
#   'py_cam2': 158,
#   'w_cam2': 48,
#   'h_cam2': 66,
#   'conf_cam2': 0.911970853805542,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.917149007320404,
#   'cls': 'roundnut',
#   'px_cam2': 164,
#   'py_cam2': 170,
#   'w_cam2': 74,
#   'h_cam2': 89,
#   'conf_cam2': 0.9009636640548706,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9160022139549255,
#   'cls': 'squarenut',
#   'px_cam2': 23,
#   'py_cam2': 159,
#   'w_cam2': 46,
#   'h_cam2': 70,
#   'conf_cam2': 0.8868573307991028,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9173063635826111,
#   'cls': 'roundnut',
#   'px_cam2': 164,
#   'py_cam2': 171,
#   'w_cam2': 76,
#   'h_cam2': 91,
#   'conf_cam2': 0.9003122448921204,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158185124397278,
#   'cls': 'squarenut',
#   'px_cam2': 22,
#   'py_cam2': 159,
#   'w_cam2': 45,
#   'h_cam2': 72,
#   'conf_cam2': 0.8667296171188354,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9179909825325012,
#   'cls': 'roundnut',
#   'px_cam2': 166,
#   'py_cam2': 171,
#   'w_cam2': 80,
#   'h_cam2': 90,
#   'conf_cam2': 0.9011603593826294,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9156934022903442,
#   'cls': 'squarenut',
#   'px_cam2': 21,
#   'py_cam2': 161,
#   'w_cam2': 42,
#   'h_cam2': 75,
#   'conf_cam2': 0.8429052829742432,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.917955219745636,
#   'cls': 'roundnut',
#   'px_cam2': 168,
#   'py_cam2': 171,
#   'w_cam2': 82,
#   'h_cam2': 90,
#   'conf_cam2': 0.90285325050354,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157459139823914,
#   'cls': 'squarenut',
#   'px_cam2': 19,
#   'py_cam2': 164,
#   'w_cam2': 39,
#   'h_cam2': 85,
#   'conf_cam2': 0.7744996547698975,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9162111878395081,
#   'cls': 'roundnut',
#   'px_cam2': 169,
#   'py_cam2': 171,
#   'w_cam2': 84,
#   'h_cam2': 90,
#   'conf_cam2': 0.9004188179969788,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9159488081932068,
#   'cls': 'squarenut',
#   'px_cam2': 17,
#   'py_cam2': 160,
#   'w_cam2': 35,
#   'h_cam2': 94,
#   'conf_cam2': 0.710199773311615,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915845513343811,
#   'cls': 'squarenut',
#   'px_cam2': 15,
#   'py_cam2': 171,
#   'w_cam2': 31,
#   'h_cam2': 123,
#   'conf_cam2': 0.41168099641799927,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9152560234069824,
#   'cls': 'roundnut',
#   'px_cam2': 171,
#   'py_cam2': 171,
#   'w_cam2': 86,
#   'h_cam2': 91,
#   'conf_cam2': 0.8951219916343689,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158046245574951,
#   'cls': 'squarenut',
#   'px_cam2': 13,
#   'py_cam2': 170,
#   'w_cam2': 27,
#   'h_cam2': 86,
#   'conf_cam2': 0.5430805683135986,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 39,
#   'conf_cam1': 0.9132047295570374,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 10,
#   'w_cam2': 69,
#   'h_cam2': 20,
#   'conf_cam2': 0.4150805175304413,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9159355163574219,
#   'cls': 'squarenut',
#   'px_cam2': 13,
#   'py_cam2': 157,
#   'w_cam2': 26,
#   'h_cam2': 102,
#   'conf_cam2': 0.35218703746795654,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 39,
#   'conf_cam1': 0.9135180711746216,
#   'cls': 'roundnut',
#   'px_cam2': 174,
#   'py_cam2': 169,
#   'w_cam2': 91,
#   'h_cam2': 92,
#   'conf_cam2': 0.9006181955337524,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158878922462463,
#   'cls': 'squarenut',
#   'px_cam2': 12,
#   'py_cam2': 153,
#   'w_cam2': 25,
#   'h_cam2': 92,
#   'conf_cam2': 0.2778913378715515,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 39,
#   'conf_cam1': 0.9145724177360535,
#   'cls': 'roundnut',
#   'px_cam2': 175,
#   'py_cam2': 170,
#   'w_cam2': 93,
#   'h_cam2': 95,
#   'conf_cam2': 0.9078642725944519,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9159405827522278,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.915511429309845,
#   'cls': 'roundnut',
#   'px_cam2': 176,
#   'py_cam2': 171,
#   'w_cam2': 95,
#   'h_cam2': 98,
#   'conf_cam2': 0.9082549214363098,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158772826194763,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 38,
#   'conf_cam1': 0.9151284098625183,
#   'cls': 'roundnut',
#   'px_cam2': 177,
#   'py_cam2': 171,
#   'w_cam2': 98,
#   'h_cam2': 100,
#   'conf_cam2': 0.9106629490852356,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9160577058792114,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 39,
#   'conf_cam1': 0.9144794940948486,
#   'cls': 'roundnut',
#   'px_cam2': 178,
#   'py_cam2': 171,
#   'w_cam2': 100,
#   'h_cam2': 101,
#   'conf_cam2': 0.9091862440109253,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9162231087684631,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 39,
#   'conf_cam1': 0.9147495031356812,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 171,
#   'w_cam2': 102,
#   'h_cam2': 102,
#   'conf_cam2': 0.9068745970726013,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9162197113037109,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 39,
#   'conf_cam1': 0.9151013493537903,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 171,
#   'w_cam2': 105,
#   'h_cam2': 103,
#   'conf_cam2': 0.9033752679824829,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.916147768497467,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 45,
#   'h_cam1': 39,
#   'conf_cam1': 0.9151609539985657,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 171,
#   'w_cam2': 106,
#   'h_cam2': 106,
#   'conf_cam2': 0.8960168957710266,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9161918759346008,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 39,
#   'conf_cam1': 0.9148523807525635,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 171,
#   'w_cam2': 109,
#   'h_cam2': 106,
#   'conf_cam2': 0.8978762030601501,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 79,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9173275232315063,
#   'cls': 'roundnut',
#   'px_cam2': 183,
#   'py_cam2': 171,
#   'w_cam2': 111,
#   'h_cam2': 107,
#   'conf_cam2': 0.8965629935264587,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9162804484367371,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9166358113288879,
#   'cls': 'roundnut',
#   'px_cam2': 184,
#   'py_cam2': 171,
#   'w_cam2': 112,
#   'h_cam2': 107,
#   'conf_cam2': 0.8970147967338562,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9163246154785156,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9161199331283569,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 37,
#   'conf_cam1': 0.914134681224823,
#   'cls': 'roundnut',
#   'px_cam2': 184,
#   'py_cam2': 172,
#   'w_cam2': 114,
#   'h_cam2': 108,
#   'conf_cam2': 0.8877551555633545,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9160259962081909,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 37,
#   'conf_cam1': 0.9138257503509521,
#   'cls': 'roundnut',
#   'px_cam2': 185,
#   'py_cam2': 171,
#   'w_cam2': 117,
#   'h_cam2': 107,
#   'conf_cam2': 0.8883225917816162,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9159674644470215,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9134090542793274,
#   'cls': 'roundnut',
#   'px_cam2': 186,
#   'py_cam2': 171,
#   'w_cam2': 118,
#   'h_cam2': 109,
#   'conf_cam2': 0.8907971382141113,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.916028618812561,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 37,
#   'conf_cam1': 0.9130964279174805,
#   'cls': 'roundnut',
#   'px_cam2': 186,
#   'py_cam2': 172,
#   'w_cam2': 121,
#   'h_cam2': 112,
#   'conf_cam2': 0.8921293020248413,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157924056053162,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.912887692451477,
#   'cls': 'roundnut',
#   'px_cam2': 187,
#   'py_cam2': 173,
#   'w_cam2': 122,
#   'h_cam2': 115,
#   'conf_cam2': 0.8931268453598022,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 104,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157831072807312,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.912779688835144,
#   'cls': 'roundnut',
#   'px_cam2': 187,
#   'py_cam2': 174,
#   'w_cam2': 124,
#   'h_cam2': 117,
#   'conf_cam2': 0.8906406164169312,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 104,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157841205596924,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9121922850608826,
#   'cls': 'roundnut',
#   'px_cam2': 187,
#   'py_cam2': 175,
#   'w_cam2': 125,
#   'h_cam2': 119,
#   'conf_cam2': 0.8900177478790283,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158903956413269,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.91338050365448,
#   'cls': 'roundnut',
#   'px_cam2': 187,
#   'py_cam2': 176,
#   'w_cam2': 127,
#   'h_cam2': 121,
#   'conf_cam2': 0.8865624666213989,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157435894012451,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9131758809089661,
#   'cls': 'roundnut',
#   'px_cam2': 187,
#   'py_cam2': 175,
#   'w_cam2': 128,
#   'h_cam2': 121,
#   'conf_cam2': 0.8839572072029114,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 104,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9156487584114075,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9135585427284241,
#   'cls': 'roundnut',
#   'px_cam2': 187,
#   'py_cam2': 176,
#   'w_cam2': 129,
#   'h_cam2': 125,
#   'conf_cam2': 0.8823723196983337,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158484935760498,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9141954183578491,
#   'cls': 'roundnut',
#   'px_cam2': 188,
#   'py_cam2': 177,
#   'w_cam2': 129,
#   'h_cam2': 126,
#   'conf_cam2': 0.8832679986953735,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 104,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9156643152236938,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9142817258834839,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 176,
#   'w_cam2': 129,
#   'h_cam2': 124,
#   'conf_cam2': 0.8826877474784851,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157238006591797,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9146609306335449,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 175,
#   'w_cam2': 129,
#   'h_cam2': 123,
#   'conf_cam2': 0.8816186785697937,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157707095146179,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9150989055633545,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 175,
#   'w_cam2': 129,
#   'h_cam2': 122,
#   'conf_cam2': 0.8828576803207397,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157505035400391,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 100,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9147589206695557,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 175,
#   'w_cam2': 130,
#   'h_cam2': 123,
#   'conf_cam2': 0.8812669515609741,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158148169517517,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9149948954582214,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 174,
#   'w_cam2': 131,
#   'h_cam2': 121,
#   'conf_cam2': 0.8802900910377502,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157136082649231,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9150458574295044,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 175,
#   'w_cam2': 131,
#   'h_cam2': 124,
#   'conf_cam2': 0.8821102976799011,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03661059365796986,
#   'world_y': -0.09740377454550436,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157971739768982,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.01074564284397464,
#   'ee_y': 0.13323589969764552,
#   'ee_z': 1.1559759483461147,
#   'world_x': 0.03473860578414316,
#   'world_y': 0.10340704750126756,
#   'world_z': 0.8299788753620365},
#  {'px_cam1': 80,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 38,
#   'conf_cam1': 0.9148479104042053,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 175,
#   'w_cam2': 132,
# ...
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 102,
#   'w_cam1': 53,
#   'h_cam1': 35,
#   'conf_cam1': 0.9161279201507568,
#   'cls': 'roundnut',
#   'px_cam2': 170,
#   'py_cam2': 172,
#   'w_cam2': 85,
#   'h_cam2': 93,
#   'conf_cam2': 0.8960723280906677,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9300658702850342,
#   'cls': 'squarenut',
#   'px_cam2': 23,
#   'py_cam2': 180,
#   'w_cam2': 46,
#   'h_cam2': 102,
#   'conf_cam2': 0.8189684152603149,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 102,
#   'w_cam1': 53,
#   'h_cam1': 35,
#   'conf_cam1': 0.9169961214065552,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 10,
#   'w_cam2': 71,
#   'h_cam2': 21,
#   'conf_cam2': 0.4014372229576111,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9301671981811523,
#   'cls': 'squarenut',
#   'px_cam2': 20,
#   'py_cam2': 178,
#   'w_cam2': 41,
#   'h_cam2': 98,
#   'conf_cam2': 0.8315816521644592,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 102,
#   'w_cam1': 53,
#   'h_cam1': 35,
#   'conf_cam1': 0.9132674336433411,
#   'cls': 'roundnut',
#   'px_cam2': 173,
#   'py_cam2': 172,
#   'w_cam2': 88,
#   'h_cam2': 94,
#   'conf_cam2': 0.9055851101875305,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9303113222122192,
#   'cls': 'squarenut',
#   'px_cam2': 19,
#   'py_cam2': 180,
#   'w_cam2': 38,
#   'h_cam2': 91,
#   'conf_cam2': 0.8043647408485413,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 102,
#   'w_cam1': 54,
#   'h_cam1': 34,
#   'conf_cam1': 0.9011755585670471,
#   'cls': 'roundnut',
#   'px_cam2': 175,
#   'py_cam2': 171,
#   'w_cam2': 90,
#   'h_cam2': 94,
#   'conf_cam2': 0.9116973280906677,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9303287863731384,
#   'cls': 'squarenut',
#   'px_cam2': 14,
#   'py_cam2': 180,
#   'w_cam2': 28,
#   'h_cam2': 92,
#   'conf_cam2': 0.7597377300262451,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 98,
#   'w_cam1': 53,
#   'h_cam1': 44,
#   'conf_cam1': 0.9070226550102234,
#   'cls': 'roundnut',
#   'px_cam2': 176,
#   'py_cam2': 172,
#   'w_cam2': 93,
#   'h_cam2': 97,
#   'conf_cam2': 0.9106362462043762,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9303319454193115,
#   'cls': 'squarenut',
#   'px_cam2': 11,
#   'py_cam2': 178,
#   'w_cam2': 23,
#   'h_cam2': 96,
#   'conf_cam2': 0.6890741586685181,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 99,
#   'w_cam1': 53,
#   'h_cam1': 40,
#   'conf_cam1': 0.8942902684211731,
#   'cls': 'roundnut',
#   'px_cam2': 177,
#   'py_cam2': 173,
#   'w_cam2': 95,
#   'h_cam2': 100,
#   'conf_cam2': 0.9025298357009888,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9300989508628845,
#   'cls': 'squarenut',
#   'px_cam2': 11,
#   'py_cam2': 178,
#   'w_cam2': 22,
#   'h_cam2': 97,
#   'conf_cam2': 0.5547074675559998,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 101,
#   'w_cam1': 54,
#   'h_cam1': 35,
#   'conf_cam1': 0.898456871509552,
#   'cls': 'roundnut',
#   'px_cam2': 178,
#   'py_cam2': 173,
#   'w_cam2': 99,
#   'h_cam2': 101,
#   'conf_cam2': 0.9008319973945618,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9301156401634216,
#   'cls': 'squarenut',
#   'px_cam2': 10,
#   'py_cam2': 177,
#   'w_cam2': 20,
#   'h_cam2': 116,
#   'conf_cam2': 0.3204345405101776,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 102,
#   'w_cam1': 54,
#   'h_cam1': 35,
#   'conf_cam1': 0.9039402604103088,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 173,
#   'w_cam2': 101,
#   'h_cam2': 102,
#   'conf_cam2': 0.893989086151123,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9301797151565552,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 102,
#   'w_cam1': 53,
#   'h_cam1': 34,
#   'conf_cam1': 0.9072685837745667,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 173,
#   'w_cam2': 101,
#   'h_cam2': 106,
#   'conf_cam2': 0.8913794755935669,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9304872751235962,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 83,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 34,
#   'conf_cam1': 0.9104024767875671,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 173,
#   'w_cam2': 103,
#   'h_cam2': 106,
#   'conf_cam2': 0.8951812386512756,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9302858710289001,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 81,
#   'py_cam1': 102,
#   'w_cam1': 49,
#   'h_cam1': 34,
#   'conf_cam1': 0.9133042097091675,
#   'cls': 'roundnut',
#   'px_cam2': 183,
#   'py_cam2': 173,
#   'w_cam2': 104,
#   'h_cam2': 106,
#   'conf_cam2': 0.8999311327934265,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9302326440811157,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 80,
#   'py_cam1': 102,
#   'w_cam1': 46,
#   'h_cam1': 34,
#   'conf_cam1': 0.9179499745368958,
#   'cls': 'roundnut',
#   'px_cam2': 184,
#   'py_cam2': 173,
#   'w_cam2': 106,
#   'h_cam2': 107,
#   'conf_cam2': 0.9003334045410156,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9301218390464783,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 80,
#   'py_cam1': 102,
#   'w_cam1': 46,
#   'h_cam1': 34,
#   'conf_cam1': 0.9181283116340637,
#   'cls': 'roundnut',
#   'px_cam2': 185,
#   'py_cam2': 174,
#   'w_cam2': 109,
#   'h_cam2': 109,
#   'conf_cam2': 0.9014341235160828,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9301880598068237,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 80,
#   'py_cam1': 102,
#   'w_cam1': 46,
#   'h_cam1': 34,
#   'conf_cam1': 0.9179713726043701,
#   'cls': 'roundnut',
#   'px_cam2': 185,
#   'py_cam2': 174,
#   'w_cam2': 110,
#   'h_cam2': 110,
#   'conf_cam2': 0.8991262912750244,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9300664663314819,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 80,
#   'py_cam1': 102,
#   'w_cam1': 46,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154989719390869,
#   'cls': 'roundnut',
#   'px_cam2': 186,
#   'py_cam2': 175,
#   'w_cam2': 112,
#   'h_cam2': 112,
#   'conf_cam2': 0.8951399326324463,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9300913214683533,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 80,
#   'py_cam1': 102,
#   'w_cam1': 46,
#   'h_cam1': 34,
#   'conf_cam1': 0.9160731434822083,
#   'cls': 'roundnut',
#   'px_cam2': 187,
#   'py_cam2': 174,
#   'w_cam2': 113,
#   'h_cam2': 111,
#   'conf_cam2': 0.8967780470848083,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9301574230194092,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 80,
#   'py_cam1': 102,
#   'w_cam1': 45,
#   'h_cam1': 34,
#   'conf_cam1': 0.9146206378936768,
#   'cls': 'roundnut',
#   'px_cam2': 188,
#   'py_cam2': 173,
#   'w_cam2': 113,
#   'h_cam2': 110,
#   'conf_cam2': 0.8906830549240112,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9300674200057983,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 80,
#   'py_cam1': 102,
#   'w_cam1': 46,
#   'h_cam1': 34,
#   'conf_cam1': 0.9169724583625793,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 175,
#   'w_cam2': 114,
#   'h_cam2': 113,
#   'conf_cam2': 0.8873791694641113,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9300211071968079,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  {'px_cam1': 80,
#   'py_cam1': 102,
#   'w_cam1': 46,
#   'h_cam1': 34,
#   'conf_cam1': 0.9160274267196655,
#   'cls': 'roundnut',
#   'px_cam2': 189,
#   'py_cam2': 174,
#   'w_cam2': 116,
#   'h_cam2': 112,
#   'conf_cam2': 0.8883510231971741,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.035153541787082014,
#   'world_y': -0.09963941076972391,
#   'world_z': 0.8299884570834555},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9300814270973206,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': 0.0035720750592096603,
#   'ee_y': 0.1320215508968297,
#   'ee_z': 1.1529159785509318,
#   'world_x': 0.02880639580181922,
#   'world_y': 0.1007575973221062,
#   'world_z': 0.8299788620969195},
#  ...]

# %%
df = pd.DataFrame(df_list)
print(df.head(5))
print(len(df))
#reverse the dict
inv_class_dict = {v: k for k, v in yolo_model.names.items()}
print(inv_class_dict)
# Replace cls names with the cls id from the yolo model
df['cls_id'] = df['cls'].map(inv_class_dict)
df.head(5)
print(len(df))
# Out:
#    px_cam1  py_cam1  w_cam1  h_cam1  conf_cam1        cls  px_cam2  py_cam2  \
# 0       79       99      45      38   0.918529   roundnut      151      152
# 1      179      103      56      34   0.915739  squarenut       44      146
# 2       79       99      45      38   0.918561   roundnut      151      151
# 3      179      103      56      34   0.915739  squarenut       44      146
# 4       79       99      45      38   0.918580   roundnut      151      152
#
#    w_cam2  h_cam2  conf_cam2      ee_x      ee_y      ee_z   world_x  \
# 0      46      57   0.952101  0.010746  0.133236  1.155976  0.036611
# 1      58      49   0.935757  0.010746  0.133236  1.155976  0.034739
# 2      46      57   0.953994  0.010746  0.133236  1.155976  0.036611
# 3      58      48   0.935890  0.010746  0.133236  1.155976  0.034739
# 4      47      57   0.954007  0.010746  0.133236  1.155976  0.036611
#
#     world_y   world_z
# 0 -0.097404  0.829988
# 1  0.103407  0.829979
# 2 -0.097404  0.829988
# 3  0.103407  0.829979
# 4 -0.097404  0.829988
# 12484

# %%
from sklearn.ensemble import GradientBoostingRegressor
X_dual = df[["px_cam1", "py_cam1", "w_cam1", "h_cam1", "conf_cam1", "px_cam2", "py_cam2", "w_cam2", "h_cam2", "conf_cam2", "ee_x", "ee_y", "ee_z"]].values
Y_dual = df[["world_x", "world_y", "world_z"]].values

reg_x_dual = GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.1)
reg_y_dual = GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.1)
reg_z_dual = GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.1)

reg_x_dual.fit(X_dual, Y_dual[:, 0])
reg_y_dual.fit(X_dual, Y_dual[:, 1])
reg_z_dual.fit(X_dual, Y_dual[:, 2])
def pixel_to_world_dual(px1, py1, w1, h1, conf1, px2, py2, w2, h2, conf2, ee_x, ee_y, ee_z):
    features = np.array([[px1, py1, w1, h1, conf1, px2, py2, w2, h2, conf2, ee_x, ee_y, ee_z]])
    x = reg_x_dual.predict(features)[0]
    y = reg_y_dual.predict(features)[0]
    z = reg_z_dual.predict(features)[0]
    return x, y, z
# --- Example usage ---
# Get a prediction for the first row of the df dataframe
px1, py1, w1, h1, conf1 = df.iloc[0][["px_cam1", "py_cam1", "w_cam1", "h_cam1", "conf_cam1"]]
px2, py2, w2, h2, conf2 = df.iloc[0][["px_cam2", "py_cam2", "w_cam2", "h_cam2", "conf_cam2"]]
ee_x, ee_y, ee_z = df.iloc[0][["ee_x", "ee_y", "ee_z"]]
print(pixel_to_world_dual(px1, py1, w1, h1, conf1, px2, py2, w2, h2, conf2, ee_x, ee_y, ee_z))
# Out:
# (0.03662168735129401, -0.09715792357140879, 0.8310022007968796)

# %%
# Replace pred columns with the dual cam predictions
df["pred_x"] = df.apply(lambda row: pixel_to_world_dual(row["px_cam1"], row["py_cam1"], row["w_cam1"], row["h_cam1"], row["conf_cam1"], row["px_cam2"], row["py_cam2"], row["w_cam2"], row["h_cam2"], row["conf_cam2"], row["ee_x"], row["ee_y"], row["ee_z"])[0], axis=1)
df["pred_y"] = df.apply(lambda row: pixel_to_world_dual(row["px_cam1"], row["py_cam1"], row["w_cam1"], row["h_cam1"], row["conf_cam1"], row["px_cam2"], row["py_cam2"], row["w_cam2"], row["h_cam2"], row["conf_cam2"], row["ee_x"], row["ee_y"], row["ee_z"])[1], axis=1)
df["pred_z"] = df.apply(lambda row: pixel_to_world_dual(row["px_cam1"], row["py_cam1"], row["w_cam1"], row["h_cam1"], row["conf_cam1"], row["px_cam2"], row["py_cam2"], row["w_cam2"], row["h_cam2"], row["conf_cam2"], row["ee_x"], row["ee_y"], row["ee_z"])[2], axis=1)

# Compute the differences between the world and predicted positions
df["diff_x"] = df["world_x"] - df["pred_x"]
df["diff_y"] = df["world_y"] - df["pred_y"]
df["diff_z"] = df["world_z"] - df["pred_z"]

# Compute the error metrics
mean_error_x = df["diff_x"].mean()
mean_error_y = df["diff_y"].mean()
mean_error_z = df["diff_z"].mean()
std_error_x = df["diff_x"].std()
std_error_y = df["diff_y"].std()
std_error_z = df["diff_z"].std()
print(f"Mean Error X: {mean_error_x}, Std Error X: {std_error_x}")
print(f"Mean Error Y: {mean_error_y}, Std Error Y: {std_error_y}")
print(f"Mean Error Z: {mean_error_z}, Std Error Z: {std_error_z}")
# Out:
# Mean Error X: 1.9395442388404577e-18, Std Error X: 0.0001581006049551298
# Mean Error Y: -2.1788260255780467e-18, Std Error Y: 0.00023408488149310455
# Mean Error Z: 1.3428682851521838e-17, Std Error Z: 0.0021298690581121014

# %%
# Save the dual cam models
joblib.dump({"reg_x": reg_x_dual, "reg_y": reg_y_dual, "reg_z": reg_z_dual}, "nutassembly_dual_cam_calibration_models.pkl")
# Out:
# ['nutassembly_dual_cam_calibration_models.pkl']
