# %%
import zipfile
import pickle
import os
import cv2
import numpy as np

def load_from_zip(zip_path):
    """
    Load pickled data stored inside a .zip file created by TrajectoryRecorder.save_buffer.
    
    Args:
        zip_path (str): Path to the .zip file.
    
    Returns:
        object: The Python object that was originally pickled (list, dict, etc.).
    """
    with zipfile.ZipFile(zip_path, 'r') as zip_file:
        with zip_file.open('data.pkl', 'r') as file:
            data = pickle.load(file)
    return data

def transform_to_list_of_images_dict(data):
    # Takes a list of type [act1, obs1, act2, obs2, ...] with obs being a dict "image_0", "image_1", "objects_pos"
    # Outputs a list of dict [obs1, obs2, ...] with obs being a dict {"_agentview":..., "wrist_image":...} 
    # image_0 is agentview, image_1 is wrist view
    images_list = []
    for episode in data:
        obs_list = []
        traj = episode[0]
        for i in range(1, len(traj), 2):
            obs = traj[i]
            if obs is None:
                continue
            img_dict = {"objects_pos": obs["objects_pos"].copy()}  # Copy the objects_pos dict
            if "image_0" in obs:
                image = obs["image_0"]
                image = cv2.flip(image.reshape(256, 256, 3), 0)
                # Change the image to BGR
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                img_dict["agentview"] = image
            if "image_1" in obs:
                image = obs["image_1"]
                image = cv2.flip(image.reshape(256, 256, 3), 0)
                # Change the image to BGR
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                img_dict["wrist_image"] = image
            obs_list.append(img_dict)
        images_list.append(obs_list)
    return images_list

# %%
# yolo imports
from ultralytics import YOLO
from roboflow import Roboflow
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2
import joblib
import pandas as pd

# %%
def get_episode_preds_and_ground_truth(episode, yolo_model):
    info_list = []
    for obs_step in episode:
        info = {}
        if "agentview" not in obs_step or "wrist_image" not in obs_step:
            continue
        agentview = obs_step["agentview"]
        wrist_image = obs_step["wrist_image"]
        # Get the predictions
        agentview_results = yolo_model(agentview, verbose=False)[0]
        wrist_results = yolo_model(wrist_image, verbose=False)[0]
        #print(obs_step.keys())
        objects_info = obs_step["objects_pos"]  # dict with object names as keys and positions as values
        for pred in agentview_results.boxes:
            cls_id = int(pred.cls)
            cls = yolo_model.names[cls_id]
            # Remove the "_" from the class name
            cls = cls.replace("_", "")
            x, y, w, h = pred.xywhn.tolist()[0]
            conf = pred.conf
            # Convert normalized coordinates to pixel coordinates
            x = int(x * agentview.shape[1])
            y = int(y * agentview.shape[0])
            w = int(w * agentview.shape[1])
            h = int(h * agentview.shape[0])

            # Convert to pixel coordinates
            x1, y1 = int(x - w / 2), int(y - h / 2)
            x2, y2 = int(x + w / 2), int(y + h / 2)

            #print(cls, objects_info.keys())
            # Get the ground truth position of the object
            if cls in objects_info:
                ground_truth_xyz = objects_info[cls]
                ee_pos = objects_info["gripper"]

                found_match = False
                for pred in wrist_results.boxes:
                    cls_id2 = int(pred.cls)
                    if cls_id2 == cls_id:
                            found_match = True
                            x_cam2, y_cam2, w_cam2, h_cam2 = pred.xywhn.tolist()[0]
                            conf_cam2 = pred.conf
                            # Convert normalized coordinates to pixel coordinates
                            x_cam2 = int(x_cam2 * wrist_image.shape[1])
                            y_cam2 = int(y_cam2 * wrist_image.shape[0])
                            w_cam2 = int(w_cam2 * wrist_image.shape[1])
                            h_cam2 = int(h_cam2 * wrist_image.shape[0])

                            info = {
                                "px_cam1": x,
                                "py_cam1": y,
                                "w_cam1": w,
                                "h_cam1": h,
                                "conf_cam1": float(conf),
                                "cls": cls,
                                "px_cam2": x_cam2,
                                "py_cam2": y_cam2,
                                "w_cam2": w_cam2,
                                "h_cam2": h_cam2,
                                "conf_cam2": float(conf_cam2),
                                "ee_x": ee_pos[0] if ee_pos is not None else None,
                                "ee_y": ee_pos[1] if ee_pos is not None else None,
                                "ee_z": ee_pos[2] if ee_pos is not None else None,
                                "world_x": ground_truth_xyz[0],
                                "world_y": ground_truth_xyz[1],
                                "world_z": ground_truth_xyz[2],
                            }
                if not found_match:
                    x_cam2, y_cam2, w_cam2, h_cam2, conf_cam2 = 0, 0, 0, 0, 0
                    info ={
                        "px_cam1": x,
                        "py_cam1": y,
                        "w_cam1": w,
                        "h_cam1": h,
                        "conf_cam1": float(conf),
                        "cls": cls,
                        "px_cam2": 0,
                        "py_cam2": 0,
                        "w_cam2": 0,
                        "h_cam2": 0,
                        "conf_cam2": 0,
                        "ee_x": ee_pos[0] if ee_pos is not None else None,
                        "ee_y": ee_pos[1] if ee_pos is not None else None,
                        "ee_z": ee_pos[2] if ee_pos is not None else None,
                        "world_x": ground_truth_xyz[0],
                        "world_y": ground_truth_xyz[1],
                        "world_z": ground_truth_xyz[2],
                        }
            info_list.append(info)
    return info_list

# %%
# Create a df that, for each label in the yolo model, gets the world_pos of the corresponding object as well as the ee_pos
df_list = []
# find all zip files in a directory
yolo_model = YOLO("../PDDL/yolo_nutassembly.pt")
data_dir = "/home/lorangpi/CyclicLxM/data/NutAssembly_seed_0/train_yolo/traces"
zip_files = [f for f in os.listdir(data_dir) if f.endswith('reach_place.zip')]
for zip_file in zip_files:
    zip_path = os.path.join(data_dir, zip_file)
    zip_name = os.path.splitext(zip_file)[0]
    videos_dir = os.path.join(data_dir, zip_name, 'videos')
    os.makedirs(videos_dir, exist_ok=True)
    yolo_data = load_from_zip(zip_path)
    h264_videos_dir = os.path.join(videos_dir, 'h264')
    os.makedirs(h264_videos_dir, exist_ok=True)
    print(f"Processing {zip_file} with {len(yolo_data)} entries")
    yolo_data = transform_to_list_of_images_dict(yolo_data)
    for episode_id, episode in enumerate(yolo_data):
        print(f"expisode {episode_id} with {len(episode)} steps")
        ep_info = get_episode_preds_and_ground_truth(episode, yolo_model)
        if len(ep_info) > 0:
            df_list.extend(ep_info)
        # if episode_id >= 10:
        #     break
# Out:
# Processing reach_place.zip with 50 entries
# expisode 0 with 146 steps
# expisode 1 with 151 steps
# expisode 2 with 155 steps
# expisode 3 with 150 steps
# expisode 4 with 147 steps
# expisode 5 with 151 steps
# expisode 6 with 163 steps
# expisode 7 with 150 steps
# expisode 8 with 159 steps
# expisode 9 with 157 steps
# expisode 10 with 187 steps
# expisode 11 with 148 steps
# expisode 12 with 149 steps
# expisode 13 with 156 steps
# expisode 14 with 158 steps
# expisode 15 with 156 steps
# expisode 16 with 154 steps
# expisode 17 with 158 steps
# expisode 18 with 146 steps
# expisode 19 with 147 steps
# expisode 20 with 154 steps
# expisode 21 with 151 steps
# expisode 22 with 155 steps
# expisode 23 with 161 steps
# expisode 24 with 151 steps
# expisode 25 with 154 steps
# expisode 26 with 152 steps
# expisode 27 with 149 steps
# expisode 28 with 155 steps
# expisode 29 with 150 steps
# expisode 30 with 150 steps
# expisode 31 with 155 steps
# expisode 32 with 146 steps
# expisode 33 with 145 steps
# expisode 34 with 149 steps
# expisode 35 with 160 steps
# expisode 36 with 149 steps
# expisode 37 with 158 steps
# expisode 38 with 153 steps
# expisode 39 with 158 steps
# expisode 40 with 145 steps
# expisode 41 with 148 steps
# expisode 42 with 171 steps
# expisode 43 with 143 steps
# expisode 44 with 148 steps
# expisode 45 with 146 steps
# expisode 46 with 147 steps
# expisode 47 with 148 steps
# expisode 48 with 154 steps
# expisode 49 with 154 steps

# %%
df_list
# Out:
# [{'px_cam1': 84,
#   'py_cam1': 100,
#   'w_cam1': 47,
#   'h_cam1': 39,
#   'conf_cam1': 0.9202125668525696,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 181,
#   'w_cam2': 139,
#   'h_cam2': 136,
#   'conf_cam2': 0.8892881274223328,
#   'ee_x': -0.119543575,
#   'ee_y': -0.07019035,
#   'ee_z': 0.8373247,
#   'world_x': -0.11533917,
#   'world_y': -0.112497576,
#   'world_z': 0.8331314},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158638715744019,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.119543575,
#   'ee_y': -0.07019035,
#   'ee_z': 0.8373247,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9159541726112366,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11942196,
#   'ee_y': -0.07079721,
#   'ee_z': 0.8439267,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 84,
#   'py_cam1': 99,
#   'w_cam1': 46,
#   'h_cam1': 39,
#   'conf_cam1': 0.9102539420127869,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 137,
#   'conf_cam2': 0.891662061214447,
#   'ee_x': -0.11942196,
#   'ee_y': -0.07079721,
#   'ee_z': 0.8439267,
#   'world_x': -0.11557887,
#   'world_y': -0.11323744,
#   'world_z': 0.8397345},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9161203503608704,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11854309,
#   'ee_y': -0.07159022,
#   'ee_z': 0.85119283,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 84,
#   'py_cam1': 97,
#   'w_cam1': 47,
#   'h_cam1': 38,
#   'conf_cam1': 0.9121008515357971,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 137,
#   'conf_cam2': 0.8910561800003052,
#   'ee_x': -0.11854309,
#   'ee_y': -0.07159022,
#   'ee_z': 0.85119283,
#   'world_x': -0.11513254,
#   'world_y': -0.11417153,
#   'world_z': 0.8470441},
#  {'px_cam1': 83,
#   'py_cam1': 95,
#   'w_cam1': 47,
#   'h_cam1': 37,
#   'conf_cam1': 0.9265297651290894,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 181,
#   'w_cam2': 141,
#   'h_cam2': 135,
#   'conf_cam2': 0.8906072378158569,
#   'ee_x': -0.118610434,
#   'ee_y': -0.07292902,
#   'ee_z': 0.85839283,
#   'world_x': -0.11563981,
#   'world_y': -0.115634345,
#   'world_z': 0.8542871},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.916015088558197,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.118610434,
#   'ee_y': -0.07292902,
#   'ee_z': 0.85839283,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 82,
#   'py_cam1': 93,
#   'w_cam1': 49,
#   'h_cam1': 38,
#   'conf_cam1': 0.9241635203361511,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 181,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8881986141204834,
#   'ee_x': -0.11929773,
#   'ee_y': -0.07325098,
#   'ee_z': 0.86590385,
#   'world_x': -0.116714925,
#   'world_y': -0.11604548,
#   'world_z': 0.86176956},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915761411190033,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11929773,
#   'ee_y': -0.07325098,
#   'ee_z': 0.86590385,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915876567363739,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11978081,
#   'ee_y': -0.07267066,
#   'ee_z': 0.8736638,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 82,
#   'py_cam1': 91,
#   'w_cam1': 48,
#   'h_cam1': 41,
#   'conf_cam1': 0.9154323935508728,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 181,
#   'w_cam2': 140,
#   'h_cam2': 133,
#   'conf_cam2': 0.8863592743873596,
#   'ee_x': -0.11978081,
#   'ee_y': -0.07267066,
#   'ee_z': 0.8736638,
#   'world_x': -0.11748851,
#   'world_y': -0.115554966,
#   'world_z': 0.86947215},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9159998893737793,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.12018593,
#   'ee_y': -0.07234503,
#   'ee_z': 0.88147527,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 82,
#   'py_cam1': 89,
#   'w_cam1': 50,
#   'h_cam1': 43,
#   'conf_cam1': 0.9110985398292542,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 132,
#   'conf_cam2': 0.8893207907676697,
#   'ee_x': -0.12018593,
#   'ee_y': -0.07234503,
#   'ee_z': 0.88147527,
#   'world_x': -0.11813247,
#   'world_y': -0.11532387,
#   'world_z': 0.87724656},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9152632355690002,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.12092019,
#   'ee_y': -0.07247818,
#   'ee_z': 0.889301,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 82,
#   'py_cam1': 87,
#   'w_cam1': 50,
#   'h_cam1': 43,
#   'conf_cam1': 0.8923166394233704,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 132,
#   'conf_cam2': 0.8876745700836182,
#   'ee_x': -0.12092019,
#   'ee_y': -0.07247818,
#   'ee_z': 0.889301,
#   'world_x': -0.11909868,
#   'world_y': -0.11545425,
#   'world_z': 0.8850526},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9151809215545654,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.12142487,
#   'ee_y': -0.073046125,
#   'ee_z': 0.8970709,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 81,
#   'py_cam1': 82,
#   'w_cam1': 50,
#   'h_cam1': 38,
#   'conf_cam1': 0.9084181785583496,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 133,
#   'conf_cam2': 0.8898594379425049,
#   'ee_x': -0.12142487,
#   'ee_y': -0.073046125,
#   'ee_z': 0.8970709,
#   'world_x': -0.11982887,
#   'world_y': -0.11605462,
#   'world_z': 0.8928457},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9152988791465759,
#   'cls': 'squarenut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.12202279,
#   'ee_y': -0.07326772,
#   'ee_z': 0.90481126,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 81,
#   'py_cam1': 79,
#   'w_cam1': 50,
#   'h_cam1': 38,
#   'conf_cam1': 0.9061833620071411,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 140,
#   'h_cam2': 133,
#   'conf_cam2': 0.8908466696739197,
#   'ee_x': -0.12202279,
#   'ee_y': -0.07326772,
#   'ee_z': 0.90481126,
#   'world_x': -0.1206078,
#   'world_y': -0.116352715,
#   'world_z': 0.9005908},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915490984916687,
#   'cls': 'squarenut',
#   'px_cam2': 12,
#   'py_cam2': 146,
#   'w_cam2': 24,
#   'h_cam2': 109,
#   'conf_cam2': 0.2831251323223114,
#   'ee_x': -0.12231593,
#   'ee_y': -0.07411602,
#   'ee_z': 0.91235375,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 81,
#   'py_cam1': 77,
#   'w_cam1': 50,
#   'h_cam1': 40,
#   'conf_cam1': 0.9081562161445618,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 140,
#   'h_cam2': 133,
#   'conf_cam2': 0.8892503380775452,
#   'ee_x': -0.12231593,
#   'ee_y': -0.07411602,
#   'ee_z': 0.91235375,
#   'world_x': -0.121071346,
#   'world_y': -0.11723209,
#   'world_z': 0.90817183},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9156222939491272,
#   'cls': 'squarenut',
#   'px_cam2': 13,
#   'py_cam2': 148,
#   'w_cam2': 27,
#   'h_cam2': 111,
#   'conf_cam2': 0.4499209225177765,
#   'ee_x': -0.122371145,
#   'ee_y': -0.075422585,
#   'ee_z': 0.91958725,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 80,
#   'py_cam1': 74,
#   'w_cam1': 51,
#   'h_cam1': 39,
#   'conf_cam1': 0.912227213382721,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 140,
#   'h_cam2': 132,
#   'conf_cam2': 0.8905813097953796,
#   'ee_x': -0.122371145,
#   'ee_y': -0.075422585,
#   'ee_z': 0.91958725,
#   'world_x': -0.121275805,
#   'world_y': -0.11846092,
#   'world_z': 0.915429},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154354333877563,
#   'cls': 'squarenut',
#   'px_cam2': 15,
#   'py_cam2': 152,
#   'w_cam2': 30,
#   'h_cam2': 96,
#   'conf_cam2': 0.5844511985778809,
#   'ee_x': -0.123983905,
#   'ee_y': -0.07642016,
#   'ee_z': 0.9266895,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 79,
#   'py_cam1': 72,
#   'w_cam1': 50,
#   'h_cam1': 39,
#   'conf_cam1': 0.9125037789344788,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 131,
#   'conf_cam2': 0.8893827199935913,
#   'ee_x': -0.123983905,
#   'ee_y': -0.07642016,
#   'ee_z': 0.9266895,
#   'world_x': -0.12301604,
#   'world_y': -0.11945222,
#   'world_z': 0.9225393},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915642261505127,
#   'cls': 'squarenut',
#   'px_cam2': 16,
#   'py_cam2': 149,
#   'w_cam2': 33,
#   'h_cam2': 90,
#   'conf_cam2': 0.6719114184379578,
#   'ee_x': -0.12645091,
#   'ee_y': -0.07746188,
#   'ee_z': 0.9338413,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 79,
#   'py_cam1': 69,
#   'w_cam1': 52,
#   'h_cam1': 39,
#   'conf_cam1': 0.9011896252632141,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 132,
#   'conf_cam2': 0.8917132019996643,
#   'ee_x': -0.12645091,
#   'ee_y': -0.07746188,
#   'ee_z': 0.9338413,
#   'world_x': -0.12559849,
#   'world_y': -0.12051143,
#   'world_z': 0.9296925},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157516360282898,
#   'cls': 'squarenut',
#   'px_cam2': 17,
#   'py_cam2': 146,
#   'w_cam2': 35,
#   'h_cam2': 74,
#   'conf_cam2': 0.7796596884727478,
#   'ee_x': -0.12697956,
#   'ee_y': -0.07784829,
#   'ee_z': 0.9411367,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 77,
#   'py_cam1': 66,
#   'w_cam1': 51,
#   'h_cam1': 40,
#   'conf_cam1': 0.894099235534668,
#   'cls': 'roundnut',
#   'px_cam2': 164,
#   'py_cam2': 10,
#   'w_cam2': 67,
#   'h_cam2': 21,
#   'conf_cam2': 0.3002423942089081,
#   'ee_x': -0.12697956,
#   'ee_y': -0.07784829,
#   'ee_z': 0.9411367,
#   'world_x': -0.1261779,
#   'world_y': -0.12094616,
#   'world_z': 0.9369622},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158073663711548,
#   'cls': 'squarenut',
#   'px_cam2': 19,
#   'py_cam2': 149,
#   'w_cam2': 38,
#   'h_cam2': 75,
#   'conf_cam2': 0.805799663066864,
#   'ee_x': -0.12753116,
#   'ee_y': -0.07820775,
#   'ee_z': 0.94854724,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 77,
#   'py_cam1': 64,
#   'w_cam1': 52,
#   'h_cam1': 39,
#   'conf_cam1': 0.903124988079071,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 140,
#   'h_cam2': 132,
#   'conf_cam2': 0.890450656414032,
#   'ee_x': -0.12753116,
#   'ee_y': -0.07820775,
#   'ee_z': 0.94854724,
#   'world_x': -0.1267705,
#   'world_y': -0.121300936,
#   'world_z': 0.9443466},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9156994223594666,
#   'cls': 'squarenut',
#   'px_cam2': 19,
#   'py_cam2': 149,
#   'w_cam2': 39,
#   'h_cam2': 74,
#   'conf_cam2': 0.8403911590576172,
#   'ee_x': -0.12864773,
#   'ee_y': -0.078867175,
#   'ee_z': 0.9561388,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 76,
#   'py_cam1': 60,
#   'w_cam1': 52,
#   'h_cam1': 40,
#   'conf_cam1': 0.9014150500297546,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 140,
#   'h_cam2': 132,
#   'conf_cam2': 0.8904812932014465,
#   'ee_x': -0.12864773,
#   'ee_y': -0.078867175,
#   'ee_z': 0.9561388,
#   'world_x': -0.12793764,
#   'world_y': -0.12195301,
#   'world_z': 0.9519294},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9160822033882141,
#   'cls': 'squarenut',
#   'px_cam2': 21,
#   'py_cam2': 146,
#   'w_cam2': 42,
#   'h_cam2': 69,
#   'conf_cam2': 0.8626748323440552,
#   'ee_x': -0.12913957,
#   'ee_y': -0.07852529,
#   'ee_z': 0.96357846,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 76,
#   'py_cam1': 57,
#   'w_cam1': 53,
#   'h_cam1': 40,
#   'conf_cam1': 0.9057053923606873,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 140,
#   'h_cam2': 132,
#   'conf_cam2': 0.8869630098342896,
#   'ee_x': -0.12913957,
#   'ee_y': -0.07852529,
#   'ee_z': 0.96357846,
#   'world_x': -0.1284392,
#   'world_y': -0.12151128,
#   'world_z': 0.9592832},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9159080982208252,
#   'cls': 'squarenut',
#   'px_cam2': 23,
#   'py_cam2': 146,
#   'w_cam2': 46,
#   'h_cam2': 69,
#   'conf_cam2': 0.8806596994400024,
#   'ee_x': -0.13012931,
#   'ee_y': -0.078840554,
#   'ee_z': 0.97092754,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 75,
#   'py_cam1': 54,
#   'w_cam1': 53,
#   'h_cam1': 39,
#   'conf_cam1': 0.9034497737884521,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 131,
#   'conf_cam2': 0.8922299146652222,
#   'ee_x': -0.13012931,
#   'ee_y': -0.078840554,
#   'ee_z': 0.97092754,
#   'world_x': -0.12946448,
#   'world_y': -0.12182795,
#   'world_z': 0.9666176},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9158053994178772,
#   'cls': 'squarenut',
#   'px_cam2': 23,
#   'py_cam2': 146,
#   'w_cam2': 46,
#   'h_cam2': 67,
#   'conf_cam2': 0.897291362285614,
#   'ee_x': -0.1311272,
#   'ee_y': -0.08015996,
#   'ee_z': 0.97825164,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 75,
#   'py_cam1': 51,
#   'w_cam1': 53,
#   'h_cam1': 39,
#   'conf_cam1': 0.9148457646369934,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 131,
#   'conf_cam2': 0.8905336856842041,
#   'ee_x': -0.1311272,
#   'ee_y': -0.08015996,
#   'ee_z': 0.97825164,
#   'world_x': -0.13052109,
#   'world_y': -0.12317135,
#   'world_z': 0.97399545},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9157499074935913,
#   'cls': 'squarenut',
#   'px_cam2': 23,
#   'py_cam2': 146,
#   'w_cam2': 47,
#   'h_cam2': 67,
#   'conf_cam2': 0.916751503944397,
#   'ee_x': -0.13160871,
#   'ee_y': -0.080752656,
#   'ee_z': 0.9855368,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 74,
#   'py_cam1': 48,
#   'w_cam1': 53,
#   'h_cam1': 40,
#   'conf_cam1': 0.9021479487419128,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 131,
#   'conf_cam2': 0.8907437920570374,
#   'ee_x': -0.13160871,
#   'ee_y': -0.080752656,
#   'ee_z': 0.9855368,
#   'world_x': -0.13102709,
#   'world_y': -0.123760514,
#   'world_z': 0.9812806},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9156628251075745,
#   'cls': 'squarenut',
#   'px_cam2': 24,
#   'py_cam2': 146,
#   'w_cam2': 48,
#   'h_cam2': 67,
#   'conf_cam2': 0.9179288744926453,
#   'ee_x': -0.13281775,
#   'ee_y': -0.081550814,
#   'ee_z': 0.9928338,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 73,
#   'py_cam1': 45,
#   'w_cam1': 53,
#   'h_cam1': 40,
#   'conf_cam1': 0.9078941941261292,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 131,
#   'conf_cam2': 0.8909891843795776,
#   'ee_x': -0.13281775,
#   'ee_y': -0.081550814,
#   'ee_z': 0.9928338,
#   'world_x': -0.1322722,
#   'world_y': -0.12454406,
#   'world_z': 0.9885847},
#  {'px_cam1': 73,
#   'py_cam1': 42,
#   'w_cam1': 52,
#   'h_cam1': 41,
#   'conf_cam1': 0.915573000907898,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 131,
#   'conf_cam2': 0.8893574476242065,
#   'ee_x': -0.13426144,
#   'ee_y': -0.08214796,
#   'ee_z': 1.0003172,
#   'world_x': -0.13374323,
#   'world_y': -0.12513901,
#   'world_z': 0.9960613},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155397415161133,
#   'cls': 'squarenut',
#   'px_cam2': 24,
#   'py_cam2': 145,
#   'w_cam2': 49,
#   'h_cam2': 65,
#   'conf_cam2': 0.9281624555587769,
#   'ee_x': -0.13426144,
#   'ee_y': -0.08214796,
#   'ee_z': 1.0003172,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9156111478805542,
#   'cls': 'squarenut',
#   'px_cam2': 26,
#   'py_cam2': 144,
#   'w_cam2': 52,
#   'h_cam2': 64,
#   'conf_cam2': 0.9326092004776001,
#   'ee_x': -0.13507207,
#   'ee_y': -0.08211763,
#   'ee_z': 1.0078441,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 72,
#   'py_cam1': 38,
#   'w_cam1': 52,
#   'h_cam1': 40,
#   'conf_cam1': 0.9135112166404724,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 141,
#   'h_cam2': 131,
#   'conf_cam2': 0.8901953101158142,
#   'ee_x': -0.13507207,
#   'ee_y': -0.08211763,
#   'ee_z': 1.0078441,
#   'world_x': -0.13455391,
#   'world_y': -0.12509707,
#   'world_z': 1.0035509},
#  {'px_cam1': 71,
#   'py_cam1': 35,
#   'w_cam1': 53,
#   'h_cam1': 40,
#   'conf_cam1': 0.9167840480804443,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 132,
#   'conf_cam2': 0.8916313052177429,
#   'ee_x': -0.13525623,
#   'ee_y': -0.08128625,
#   'ee_z': 1.0150331,
#   'world_x': -0.13471502,
#   'world_y': -0.12420955,
#   'world_z': 1.0106616},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155449271202087,
#   'cls': 'squarenut',
#   'px_cam2': 27,
#   'py_cam2': 143,
#   'w_cam2': 54,
#   'h_cam2': 64,
#   'conf_cam2': 0.9367722272872925,
#   'ee_x': -0.13525623,
#   'ee_y': -0.08128625,
#   'ee_z': 1.0150331,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154902696609497,
#   'cls': 'squarenut',
#   'px_cam2': 28,
#   'py_cam2': 143,
#   'w_cam2': 56,
#   'h_cam2': 62,
#   'conf_cam2': 0.9408435225486755,
#   'ee_x': -0.13560745,
#   'ee_y': -0.081944525,
#   'ee_z': 1.0219154,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 71,
#   'py_cam1': 32,
#   'w_cam1': 53,
#   'h_cam1': 40,
#   'conf_cam1': 0.9063478112220764,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 132,
#   'conf_cam2': 0.8922055959701538,
#   'ee_x': -0.13560745,
#   'ee_y': -0.081944525,
#   'ee_z': 1.0219154,
#   'world_x': -0.13509901,
#   'world_y': -0.12488882,
#   'world_z': 1.0175824},
#  {'px_cam1': 71,
#   'py_cam1': 29,
#   'w_cam1': 53,
#   'h_cam1': 39,
#   'conf_cam1': 0.9216823577880859,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 131,
#   'conf_cam2': 0.892937421798706,
#   'ee_x': -0.13654198,
#   'ee_y': -0.08249992,
#   'ee_z': 1.0290585,
#   'world_x': -0.136068,
#   'world_y': -0.12547936,
#   'world_z': 1.0247524},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915517270565033,
#   'cls': 'squarenut',
#   'px_cam2': 28,
#   'py_cam2': 143,
#   'w_cam2': 57,
#   'h_cam2': 61,
#   'conf_cam2': 0.9458485841751099,
#   'ee_x': -0.13654198,
#   'ee_y': -0.08249992,
#   'ee_z': 1.0290585,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 27,
#   'w_cam1': 54,
#   'h_cam1': 38,
#   'conf_cam1': 0.9213692545890808,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 131,
#   'conf_cam2': 0.8922471404075623,
#   'ee_x': -0.13894509,
#   'ee_y': -0.08276871,
#   'ee_z': 1.0362573,
#   'world_x': -0.13851438,
#   'world_y': -0.12575279,
#   'world_z': 1.0319451},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155876636505127,
#   'cls': 'squarenut',
#   'px_cam2': 28,
#   'py_cam2': 142,
#   'w_cam2': 57,
#   'h_cam2': 59,
#   'conf_cam2': 0.9487668871879578,
#   'ee_x': -0.13894509,
#   'ee_y': -0.08276871,
#   'ee_z': 1.0362573,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155263304710388,
#   'cls': 'squarenut',
#   'px_cam2': 29,
#   'py_cam2': 140,
#   'w_cam2': 59,
#   'h_cam2': 58,
#   'conf_cam2': 0.9460054636001587,
#   'ee_x': -0.14088705,
#   'ee_y': -0.083610736,
#   'ee_z': 1.0436449,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 22,
#   'w_cam1': 55,
#   'h_cam1': 40,
#   'conf_cam1': 0.9074358940124512,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 132,
#   'conf_cam2': 0.8915839791297913,
#   'ee_x': -0.14088705,
#   'ee_y': -0.083610736,
#   'ee_z': 1.0436449,
#   'world_x': -0.14050281,
#   'world_y': -0.12660418,
#   'world_z': 1.0393605},
#  {'px_cam1': 69,
#   'py_cam1': 19,
#   'w_cam1': 55,
#   'h_cam1': 38,
#   'conf_cam1': 0.9225439429283142,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 132,
#   'conf_cam2': 0.8907315731048584,
#   'ee_x': -0.14186428,
#   'ee_y': -0.08456217,
#   'ee_z': 1.05112,
#   'world_x': -0.14150073,
#   'world_y': -0.1275685,
#   'world_z': 1.0468696},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155492186546326,
#   'cls': 'squarenut',
#   'px_cam2': 29,
#   'py_cam2': 139,
#   'w_cam2': 59,
#   'h_cam2': 57,
#   'conf_cam2': 0.95430988073349,
#   'ee_x': -0.14186428,
#   'ee_y': -0.08456217,
#   'ee_z': 1.05112,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155882000923157,
#   'cls': 'squarenut',
#   'px_cam2': 30,
#   'py_cam2': 138,
#   'w_cam2': 60,
#   'h_cam2': 56,
#   'conf_cam2': 0.9529719352722168,
#   'ee_x': -0.1423696,
#   'ee_y': -0.084933676,
#   'ee_z': 1.0585403,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 17,
#   'w_cam1': 55,
#   'h_cam1': 34,
#   'conf_cam1': 0.907697856426239,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 182,
#   'w_cam2': 141,
#   'h_cam2': 131,
#   'conf_cam2': 0.8899181485176086,
#   'ee_x': -0.1423696,
#   'ee_y': -0.084933676,
#   'ee_z': 1.0585403,
#   'world_x': -0.14199254,
#   'world_y': -0.1279477,
#   'world_z': 1.0542876},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155817031860352,
#   'cls': 'squarenut',
#   'px_cam2': 31,
#   'py_cam2': 138,
#   'w_cam2': 62,
#   'h_cam2': 54,
#   'conf_cam2': 0.9486610293388367,
#   'ee_x': -0.14309576,
#   'ee_y': -0.08529771,
#   'ee_z': 1.0659503,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 67,
#   'py_cam1': 15,
#   'w_cam1': 55,
#   'h_cam1': 31,
#   'conf_cam1': 0.9102132320404053,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 132,
#   'conf_cam2': 0.8903685212135315,
#   'ee_x': -0.14309576,
#   'ee_y': -0.08529771,
#   'ee_z': 1.0659503,
#   'world_x': -0.14270896,
#   'world_y': -0.12831776,
#   'world_z': 1.0616975},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155805706977844,
#   'cls': 'squarenut',
#   'px_cam2': 32,
#   'py_cam2': 137,
#   'w_cam2': 62,
#   'h_cam2': 53,
#   'conf_cam2': 0.9437380433082581,
#   'ee_x': -0.14413778,
#   'ee_y': -0.08541951,
#   'ee_z': 1.0734478,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 66,
#   'py_cam1': 14,
#   'w_cam1': 55,
#   'h_cam1': 28,
#   'conf_cam1': 0.9024277329444885,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 132,
#   'conf_cam2': 0.8918547034263611,
#   'ee_x': -0.14413778,
#   'ee_y': -0.08541951,
#   'ee_z': 1.0734478,
#   'world_x': -0.14374231,
#   'world_y': -0.12844779,
#   'world_z': 1.0691822},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155879020690918,
#   'cls': 'squarenut',
#   'px_cam2': 33,
#   'py_cam2': 137,
#   'w_cam2': 63,
#   'h_cam2': 52,
#   'conf_cam2': 0.9411051869392395,
#   'ee_x': -0.14528391,
#   'ee_y': -0.08507106,
#   'ee_z': 1.0809995,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 65,
#   'py_cam1': 12,
#   'w_cam1': 56,
#   'h_cam1': 25,
#   'conf_cam1': 0.9099635481834412,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 132,
#   'conf_cam2': 0.8914950489997864,
#   'ee_x': -0.14528391,
#   'ee_y': -0.08507106,
#   'ee_z': 1.0809995,
#   'world_x': -0.14487453,
#   'world_y': -0.12811033,
#   'world_z': 1.0767018},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155663847923279,
#   'cls': 'squarenut',
#   'px_cam2': 35,
#   'py_cam2': 136,
#   'w_cam2': 61,
#   'h_cam2': 50,
#   'conf_cam2': 0.9361704587936401,
#   'ee_x': -0.1469177,
#   'ee_y': -0.08493641,
#   'ee_z': 1.0885669,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 65,
#   'py_cam1': 11,
#   'w_cam1': 57,
#   'h_cam1': 22,
#   'conf_cam1': 0.8571648597717285,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 183,
#   'w_cam2': 141,
#   'h_cam2': 132,
#   'conf_cam2': 0.8916657567024231,
#   'ee_x': -0.1469177,
#   'ee_y': -0.08493641,
#   'ee_z': 1.0885669,
#   'world_x': -0.14651823,
#   'world_y': -0.12798291,
#   'world_z': 1.084259},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155403971672058,
#   'cls': 'squarenut',
#   'px_cam2': 37,
#   'py_cam2': 135,
#   'w_cam2': 60,
#   'h_cam2': 50,
#   'conf_cam2': 0.9373003840446472,
#   'ee_x': -0.14778684,
#   'ee_y': -0.084671326,
#   'ee_z': 1.0961142,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 72,
#   'py_cam1': 10,
#   'w_cam1': 66,
#   'h_cam1': 21,
#   'conf_cam1': 0.7380669116973877,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 182,
#   'w_cam2': 140,
#   'h_cam2': 131,
#   'conf_cam2': 0.8947614431381226,
#   'ee_x': -0.14778684,
#   'ee_y': -0.084671326,
#   'ee_z': 1.0961142,
#   'world_x': -0.14738138,
#   'world_y': -0.12772451,
#   'world_z': 1.091797},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155177474021912,
#   'cls': 'squarenut',
#   'px_cam2': 39,
#   'py_cam2': 134,
#   'w_cam2': 58,
#   'h_cam2': 49,
#   'conf_cam2': 0.944631814956665,
#   'ee_x': -0.14829916,
#   'ee_y': -0.08329191,
#   'ee_z': 1.1032506,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 6,
#   'w_cam1': 66,
#   'h_cam1': 13,
#   'conf_cam1': 0.6029125452041626,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 183,
#   'w_cam2': 140,
#   'h_cam2': 132,
#   'conf_cam2': 0.8944551944732666,
#   'ee_x': -0.14829916,
#   'ee_y': -0.08329191,
#   'ee_z': 1.1032506,
#   'world_x': -0.14784873,
#   'world_y': -0.12634811,
#   'world_z': 1.0988692},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154644012451172,
#   'cls': 'squarenut',
#   'px_cam2': 42,
#   'py_cam2': 134,
#   'w_cam2': 56,
#   'h_cam2': 47,
#   'conf_cam2': 0.9449703097343445,
#   'ee_x': -0.15025753,
#   'ee_y': -0.08239604,
#   'ee_z': 1.1103065,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154685139656067,
#   'cls': 'squarenut',
#   'px_cam2': 43,
#   'py_cam2': 133,
#   'w_cam2': 56,
#   'h_cam2': 46,
#   'conf_cam2': 0.9317116141319275,
#   'ee_x': -0.1521511,
#   'ee_y': -0.08278781,
#   'ee_z': 1.1177458,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154592156410217,
#   'cls': 'squarenut',
#   'px_cam2': 44,
#   'py_cam2': 132,
#   'w_cam2': 56,
#   'h_cam2': 46,
#   'conf_cam2': 0.9307640790939331,
#   'ee_x': -0.15322943,
#   'ee_y': -0.08319624,
#   'ee_z': 1.1252975,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154657125473022,
#   'cls': 'squarenut',
#   'px_cam2': 45,
#   'py_cam2': 132,
#   'w_cam2': 55,
#   'h_cam2': 45,
#   'conf_cam2': 0.9298382997512817,
#   'ee_x': -0.15120104,
#   'ee_y': -0.082838915,
#   'ee_z': 1.1281563,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915489673614502,
#   'cls': 'squarenut',
#   'px_cam2': 45,
#   'py_cam2': 133,
#   'w_cam2': 54,
#   'h_cam2': 44,
#   'conf_cam2': 0.927471399307251,
#   'ee_x': -0.14657883,
#   'ee_y': -0.082467854,
#   'ee_z': 1.1271387,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154657125473022,
#   'cls': 'squarenut',
#   'px_cam2': 46,
#   'py_cam2': 135,
#   'w_cam2': 54,
#   'h_cam2': 46,
#   'conf_cam2': 0.9190383553504944,
#   'ee_x': -0.14170994,
#   'ee_y': -0.081841305,
#   'ee_z': 1.1264423,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154576659202576,
#   'cls': 'squarenut',
#   'px_cam2': 46,
#   'py_cam2': 137,
#   'w_cam2': 54,
#   'h_cam2': 45,
#   'conf_cam2': 0.9191191792488098,
#   'ee_x': -0.13654694,
#   'ee_y': -0.08034172,
#   'ee_z': 1.1254028,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154368042945862,
#   'cls': 'squarenut',
#   'px_cam2': 47,
#   'py_cam2': 140,
#   'w_cam2': 55,
#   'h_cam2': 46,
#   'conf_cam2': 0.9230413436889648,
#   'ee_x': -0.13097358,
#   'ee_y': -0.07865325,
#   'ee_z': 1.1241888,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915458083152771,
#   'cls': 'squarenut',
#   'px_cam2': 47,
#   'py_cam2': 142,
#   'w_cam2': 54,
#   'h_cam2': 45,
#   'conf_cam2': 0.9298549294471741,
#   'ee_x': -0.125286,
#   'ee_y': -0.07741392,
#   'ee_z': 1.1229054,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154235124588013,
#   'cls': 'squarenut',
#   'px_cam2': 47,
#   'py_cam2': 144,
#   'w_cam2': 54,
#   'h_cam2': 46,
#   'conf_cam2': 0.9206445813179016,
#   'ee_x': -0.119520366,
#   'ee_y': -0.0768866,
#   'ee_z': 1.1220189,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154545068740845,
#   'cls': 'squarenut',
#   'px_cam2': 47,
#   'py_cam2': 147,
#   'w_cam2': 56,
#   'h_cam2': 46,
#   'conf_cam2': 0.9254757761955261,
#   'ee_x': -0.11382817,
#   'ee_y': -0.075881,
#   'ee_z': 1.1212668,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154582023620605,
#   'cls': 'squarenut',
#   'px_cam2': 47,
#   'py_cam2': 149,
#   'w_cam2': 56,
#   'h_cam2': 46,
#   'conf_cam2': 0.9222082495689392,
#   'ee_x': -0.10851047,
#   'ee_y': -0.07450928,
#   'ee_z': 1.1206795,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.915440022945404,
#   'cls': 'squarenut',
#   'px_cam2': 48,
#   'py_cam2': 151,
#   'w_cam2': 55,
#   'h_cam2': 46,
#   'conf_cam2': 0.9282357692718506,
#   'ee_x': -0.10263381,
#   'ee_y': -0.072281495,
#   'ee_z': 1.1200228,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154362082481384,
#   'cls': 'squarenut',
#   'px_cam2': 49,
#   'py_cam2': 153,
#   'w_cam2': 55,
#   'h_cam2': 46,
#   'conf_cam2': 0.9261349439620972,
#   'ee_x': -0.09670053,
#   'ee_y': -0.07044262,
#   'ee_z': 1.1187084,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 66,
#   'py_cam1': 5,
#   'w_cam1': 71,
#   'h_cam1': 10,
#   'conf_cam1': 0.3177056610584259,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 184,
#   'w_cam2': 139,
#   'h_cam2': 134,
#   'conf_cam2': 0.8894864320755005,
#   'ee_x': -0.09670053,
#   'ee_y': -0.07044262,
#   'ee_z': 1.1187084,
#   'world_x': -0.09627819,
#   'world_y': -0.113517,
#   'world_z': 1.1145363},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154490828514099,
#   'cls': 'squarenut',
#   'px_cam2': 49,
#   'py_cam2': 155,
#   'w_cam2': 56,
#   'h_cam2': 46,
#   'conf_cam2': 0.9225270748138428,
#   'ee_x': -0.09070792,
#   'ee_y': -0.06884987,
#   'ee_z': 1.1175104,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 67,
#   'py_cam1': 6,
#   'w_cam1': 64,
#   'h_cam1': 13,
#   'conf_cam1': 0.529159665107727,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 184,
#   'w_cam2': 140,
#   'h_cam2': 134,
#   'conf_cam2': 0.8900150656700134,
#   'ee_x': -0.09070792,
#   'ee_y': -0.06884987,
#   'ee_z': 1.1175104,
#   'world_x': -0.090310365,
#   'world_y': -0.11193862,
#   'world_z': 1.1133617},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154742956161499,
#   'cls': 'squarenut',
#   'px_cam2': 49,
#   'py_cam2': 157,
#   'w_cam2': 56,
#   'h_cam2': 46,
#   'conf_cam2': 0.9308094382286072,
#   'ee_x': -0.08417839,
#   'ee_y': -0.06731229,
#   'ee_z': 1.1164484,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 64,
#   'py_cam1': 7,
#   'w_cam1': 56,
#   'h_cam1': 14,
#   'conf_cam1': 0.6955978870391846,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 140,
#   'h_cam2': 134,
#   'conf_cam2': 0.8914884924888611,
#   'ee_x': -0.08417839,
#   'ee_y': -0.06731229,
#   'ee_z': 1.1164484,
#   'world_x': -0.083800875,
#   'world_y': -0.110412896,
#   'world_z': 1.1123291},
#  {'px_cam1': 68,
#   'py_cam1': 8,
#   'w_cam1': 66,
#   'h_cam1': 17,
#   'conf_cam1': 0.30050382018089294,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 140,
#   'h_cam2': 134,
#   'conf_cam2': 0.8914884924888611,
#   'ee_x': -0.08417839,
#   'ee_y': -0.06731229,
#   'ee_z': 1.1164484,
#   'world_x': -0.083800875,
#   'world_y': -0.110412896,
#   'world_z': 1.1123291},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154753684997559,
#   'cls': 'squarenut',
#   'px_cam2': 50,
#   'py_cam2': 160,
#   'w_cam2': 55,
#   'h_cam2': 46,
#   'conf_cam2': 0.9292251467704773,
#   'ee_x': -0.07789543,
#   'ee_y': -0.06629651,
#   'ee_z': 1.1149218,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 10,
#   'w_cam1': 63,
#   'h_cam1': 19,
#   'conf_cam1': 0.7088112235069275,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 140,
#   'h_cam2': 134,
#   'conf_cam2': 0.8919015526771545,
#   'ee_x': -0.07789543,
#   'ee_y': -0.06629651,
#   'ee_z': 1.1149218,
#   'world_x': -0.077554576,
#   'world_y': -0.10940181,
#   'world_z': 1.110858},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154744744300842,
#   'cls': 'squarenut',
#   'px_cam2': 50,
#   'py_cam2': 162,
#   'w_cam2': 56,
#   'h_cam2': 46,
#   'conf_cam2': 0.9313276410102844,
#   'ee_x': -0.07214648,
#   'ee_y': -0.06476721,
#   'ee_z': 1.114059,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 11,
#   'w_cam1': 62,
#   'h_cam1': 22,
#   'conf_cam1': 0.8301267027854919,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 184,
#   'w_cam2': 140,
#   'h_cam2': 134,
#   'conf_cam2': 0.893492579460144,
#   'ee_x': -0.07214648,
#   'ee_y': -0.06476721,
#   'ee_z': 1.114059,
#   'world_x': -0.071824335,
#   'world_y': -0.10787557,
#   'world_z': 1.1099986},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155065417289734,
#   'cls': 'squarenut',
#   'px_cam2': 50,
#   'py_cam2': 165,
#   'w_cam2': 55,
#   'h_cam2': 46,
#   'conf_cam2': 0.9283320307731628,
#   'ee_x': -0.066017434,
#   'ee_y': -0.06354952,
#   'ee_z': 1.1130795,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 69,
#   'py_cam1': 11,
#   'w_cam1': 65,
#   'h_cam1': 23,
#   'conf_cam1': 0.8153458833694458,
#   'cls': 'roundnut',
#   'px_cam2': 181,
#   'py_cam2': 184,
#   'w_cam2': 140,
#   'h_cam2': 134,
#   'conf_cam2': 0.893473744392395,
#   'ee_x': -0.066017434,
#   'ee_y': -0.06354952,
#   'ee_z': 1.1130795,
#   'world_x': -0.065714926,
#   'world_y': -0.10666671,
#   'world_z': 1.1090453},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155186414718628,
#   'cls': 'squarenut',
#   'px_cam2': 50,
#   'py_cam2': 168,
#   'w_cam2': 56,
#   'h_cam2': 48,
#   'conf_cam2': 0.9317377209663391,
#   'ee_x': -0.060126495,
#   'ee_y': -0.062413037,
#   'ee_z': 1.1121955,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 12,
#   'w_cam1': 68,
#   'h_cam1': 24,
#   'conf_cam1': 0.8521376848220825,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 135,
#   'conf_cam2': 0.8936247825622559,
#   'ee_x': -0.060126495,
#   'ee_y': -0.062413037,
#   'ee_z': 1.1121955,
#   'world_x': -0.059841335,
#   'world_y': -0.10554795,
#   'world_z': 1.1081836},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155400395393372,
#   'cls': 'squarenut',
#   'px_cam2': 51,
#   'py_cam2': 170,
#   'w_cam2': 55,
#   'h_cam2': 49,
#   'conf_cam2': 0.929046094417572,
#   'ee_x': -0.05439432,
#   'ee_y': -0.061150108,
#   'ee_z': 1.1123252,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 69,
#   'py_cam1': 13,
#   'w_cam1': 64,
#   'h_cam1': 26,
#   'conf_cam1': 0.8666321039199829,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8919592499732971,
#   'ee_x': -0.05439432,
#   'ee_y': -0.061150108,
#   'ee_z': 1.1123252,
#   'world_x': -0.054116648,
#   'world_y': -0.10428487,
#   'world_z': 1.1083124},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155393242835999,
#   'cls': 'squarenut',
#   'px_cam2': 52,
#   'py_cam2': 172,
#   'w_cam2': 55,
#   'h_cam2': 49,
#   'conf_cam2': 0.9249793291091919,
#   'ee_x': -0.048935566,
#   'ee_y': -0.060214967,
#   'ee_z': 1.1120054,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 69,
#   'py_cam1': 13,
#   'w_cam1': 65,
#   'h_cam1': 27,
#   'conf_cam1': 0.8785303235054016,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8921410441398621,
#   'ee_x': -0.048935566,
#   'ee_y': -0.060214967,
#   'ee_z': 1.1120054,
#   'world_x': -0.0486739,
#   'world_y': -0.10336874,
#   'world_z': 1.1080122},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155049324035645,
#   'cls': 'squarenut',
#   'px_cam2': 52,
#   'py_cam2': 173,
#   'w_cam2': 56,
#   'h_cam2': 48,
#   'conf_cam2': 0.9267339110374451,
#   'ee_x': -0.043828677,
#   'ee_y': -0.059287045,
#   'ee_z': 1.1113364,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 69,
#   'py_cam1': 14,
#   'w_cam1': 65,
#   'h_cam1': 29,
#   'conf_cam1': 0.8992846608161926,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8917925357818604,
#   'ee_x': -0.043828677,
#   'ee_y': -0.059287045,
#   'ee_z': 1.1113364,
#   'world_x': -0.043582067,
#   'world_y': -0.102448165,
#   'world_z': 1.1073494},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154866933822632,
#   'cls': 'squarenut',
#   'px_cam2': 52,
#   'py_cam2': 176,
#   'w_cam2': 55,
#   'h_cam2': 49,
#   'conf_cam2': 0.9300287365913391,
#   'ee_x': -0.03858953,
#   'ee_y': -0.058108065,
#   'ee_z': 1.1105111,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 69,
#   'py_cam1': 15,
#   'w_cam1': 65,
#   'h_cam1': 31,
#   'conf_cam1': 0.9086076021194458,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.891262412071228,
#   'ee_x': -0.03858953,
#   'ee_y': -0.058108065,
#   'ee_z': 1.1105111,
#   'world_x': -0.03834431,
#   'world_y': -0.10127292,
#   'world_z': 1.1065078},
#  {'px_cam1': 70,
#   'py_cam1': 16,
#   'w_cam1': 66,
#   'h_cam1': 33,
#   'conf_cam1': 0.9178898334503174,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 140,
#   'h_cam2': 134,
#   'conf_cam2': 0.8915485739707947,
#   'ee_x': -0.033356857,
#   'ee_y': -0.057532005,
#   'ee_z': 1.1100336,
#   'world_x': -0.03312637,
#   'world_y': -0.10069338,
#   'world_z': 1.1060507},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155152440071106,
#   'cls': 'squarenut',
#   'px_cam2': 53,
#   'py_cam2': 178,
#   'w_cam2': 56,
#   'h_cam2': 50,
#   'conf_cam2': 0.9234797954559326,
#   'ee_x': -0.033356857,
#   'ee_y': -0.057532005,
#   'ee_z': 1.1100336,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 16,
#   'w_cam1': 66,
#   'h_cam1': 33,
#   'conf_cam1': 0.9228301048278809,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8937928676605225,
#   'ee_x': -0.028347947,
#   'ee_y': -0.057017274,
#   'ee_z': 1.1097473,
#   'world_x': -0.028127318,
#   'world_y': -0.10019357,
#   'world_z': 1.1057796},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155184626579285,
#   'cls': 'squarenut',
#   'px_cam2': 52,
#   'py_cam2': 180,
#   'w_cam2': 57,
#   'h_cam2': 49,
#   'conf_cam2': 0.9222419857978821,
#   'ee_x': -0.028347947,
#   'ee_y': -0.057017274,
#   'ee_z': 1.1097473,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 18,
#   'w_cam1': 66,
#   'h_cam1': 36,
#   'conf_cam1': 0.9209689497947693,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8927724957466125,
#   'ee_x': -0.023797499,
#   'ee_y': -0.05642059,
#   'ee_z': 1.1095634,
#   'world_x': -0.02358303,
#   'world_y': -0.09960267,
#   'world_z': 1.1055933},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9154807925224304,
#   'cls': 'squarenut',
#   'px_cam2': 53,
#   'py_cam2': 181,
#   'w_cam2': 56,
#   'h_cam2': 47,
#   'conf_cam2': 0.912165105342865,
#   'ee_x': -0.023797499,
#   'ee_y': -0.05642059,
#   'ee_z': 1.1095634,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 18,
#   'w_cam1': 66,
#   'h_cam1': 37,
#   'conf_cam1': 0.925827145576477,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8928134441375732,
#   'ee_x': -0.019574681,
#   'ee_y': -0.055896822,
#   'ee_z': 1.1097244,
#   'world_x': -0.01936649,
#   'world_y': -0.09907663,
#   'world_z': 1.1057472},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155262112617493,
#   'cls': 'squarenut',
#   'px_cam2': 53,
#   'py_cam2': 181,
#   'w_cam2': 56,
#   'h_cam2': 45,
#   'conf_cam2': 0.9195858240127563,
#   'ee_x': -0.019574681,
#   'ee_y': -0.055896822,
#   'ee_z': 1.1097244,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 19,
#   'w_cam1': 67,
#   'h_cam1': 39,
#   'conf_cam1': 0.9438066482543945,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.893336296081543,
#   'ee_x': -0.015672559,
#   'ee_y': -0.05544933,
#   'ee_z': 1.1102473,
#   'world_x': -0.015469763,
#   'world_y': -0.09864393,
#   'world_z': 1.1062669},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155335426330566,
#   'cls': 'squarenut',
#   'px_cam2': 53,
#   'py_cam2': 182,
#   'w_cam2': 56,
#   'h_cam2': 44,
#   'conf_cam2': 0.915345311164856,
#   'ee_x': -0.015672559,
#   'ee_y': -0.05544933,
#   'ee_z': 1.1102473,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 20,
#   'w_cam1': 68,
#   'h_cam1': 40,
#   'conf_cam1': 0.9429185390472412,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8949347138404846,
#   'ee_x': -0.011950176,
#   'ee_y': -0.055096883,
#   'ee_z': 1.1109457,
#   'world_x': -0.011752284,
#   'world_y': -0.098293036,
#   'world_z': 1.106961},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155400991439819,
#   'cls': 'squarenut',
#   'px_cam2': 53,
#   'py_cam2': 183,
#   'w_cam2': 56,
#   'h_cam2': 42,
#   'conf_cam2': 0.9162269234657288,
#   'ee_x': -0.011950176,
#   'ee_y': -0.055096883,
#   'ee_z': 1.1109457,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 20,
#   'w_cam1': 68,
#   'h_cam1': 40,
#   'conf_cam1': 0.9429190754890442,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8955782055854797,
#   'ee_x': -0.008564252,
#   'ee_y': -0.05465477,
#   'ee_z': 1.1114292,
#   'world_x': -0.008366496,
#   'world_y': -0.097857825,
#   'world_z': 1.1074332},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155395030975342,
#   'cls': 'squarenut',
#   'px_cam2': 53,
#   'py_cam2': 183,
#   'w_cam2': 56,
#   'h_cam2': 42,
#   'conf_cam2': 0.9154670834541321,
#   'ee_x': -0.008564252,
#   'ee_y': -0.05465477,
#   'ee_z': 1.1114292,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 21,
#   'w_cam1': 68,
#   'h_cam1': 42,
#   'conf_cam1': 0.938941240310669,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 134,
#   'conf_cam2': 0.8947018384933472,
#   'ee_x': -0.005171823,
#   'ee_y': -0.054253962,
#   'ee_z': 1.1119485,
#   'world_x': -0.0049745888,
#   'world_y': -0.097463034,
#   'world_z': 1.1079452},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155303239822388,
#   'cls': 'squarenut',
#   'px_cam2': 54,
#   'py_cam2': 186,
#   'w_cam2': 56,
#   'h_cam2': 46,
#   'conf_cam2': 0.9020159840583801,
#   'ee_x': -0.005171823,
#   'ee_y': -0.054253962,
#   'ee_z': 1.1119485,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 70,
#   'py_cam1': 21,
#   'w_cam1': 69,
#   'h_cam1': 43,
#   'conf_cam1': 0.9353432059288025,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 133,
#   'conf_cam2': 0.8939986228942871,
#   'ee_x': -0.0018687373,
#   'ee_y': -0.054016877,
#   'ee_z': 1.1125891,
#   'world_x': -0.0016753236,
#   'world_y': -0.09723017,
#   'world_z': 1.1085877},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155313372612,
#   'cls': 'squarenut',
#   'px_cam2': 54,
#   'py_cam2': 186,
#   'w_cam2': 57,
#   'h_cam2': 44,
#   'conf_cam2': 0.9075026512145996,
#   'ee_x': -0.0018687373,
#   'ee_y': -0.054016877,
#   'ee_z': 1.1125891,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
#   'world_z': 0.82997894},
#  {'px_cam1': 69,
#   'py_cam1': 21,
#   'w_cam1': 68,
#   'h_cam1': 43,
#   'conf_cam1': 0.9354114532470703,
#   'cls': 'roundnut',
#   'px_cam2': 182,
#   'py_cam2': 184,
#   'w_cam2': 141,
#   'h_cam2': 133,
#   'conf_cam2': 0.8942419290542603,
#   'ee_x': 0.0010668293,
#   'ee_y': -0.053797845,
#   'ee_z': 1.1130308,
#   'world_x': 0.0012543078,
#   'world_y': -0.097011864,
#   'world_z': 1.1090275},
#  {'px_cam1': 179,
#   'py_cam1': 103,
#   'w_cam1': 56,
#   'h_cam1': 34,
#   'conf_cam1': 0.9155570864677429,
#   'cls': 'squarenut',
#   'px_cam2': 55,
#   'py_cam2': 185,
#   'w_cam2': 57,
#   'h_cam2': 41,
#   'conf_cam2': 0.8956255316734314,
#   'ee_x': 0.0010668293,
#   'ee_y': -0.053797845,
#   'ee_z': 1.1130308,
#   'world_x': -0.11150381,
#   'world_y': 0.1442081,
# ...
#   'h_cam1': 32,
#   'conf_cam1': 0.9292747974395752,
#   'cls': 'squarenut',
#   'px_cam2': 58,
#   'py_cam2': 175,
#   'w_cam2': 50,
#   'h_cam2': 46,
#   'conf_cam2': 0.9138516783714294,
#   'ee_x': -0.03324825,
#   'ee_y': -0.058865156,
#   'ee_z': 1.1192648,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 69,
#   'py_cam1': 14,
#   'w_cam1': 66,
#   'h_cam1': 28,
#   'conf_cam1': 0.8885929584503174,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 182,
#   'w_cam2': 131,
#   'h_cam2': 122,
#   'conf_cam2': 0.8648090362548828,
#   'ee_x': -0.03324825,
#   'ee_y': -0.058865156,
#   'ee_z': 1.1192648,
#   'world_x': -0.03072901,
#   'world_y': -0.10087261,
#   'world_z': 1.1144102},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292605519294739,
#   'cls': 'squarenut',
#   'px_cam2': 58,
#   'py_cam2': 177,
#   'w_cam2': 49,
#   'h_cam2': 48,
#   'conf_cam2': 0.9073216915130615,
#   'ee_x': -0.028245768,
#   'ee_y': -0.058325727,
#   'ee_z': 1.1193631,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 15,
#   'w_cam1': 66,
#   'h_cam1': 30,
#   'conf_cam1': 0.9028845429420471,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 182,
#   'w_cam2': 131,
#   'h_cam2': 123,
#   'conf_cam2': 0.864649772644043,
#   'ee_x': -0.028245768,
#   'ee_y': -0.058325727,
#   'ee_z': 1.1193631,
#   'world_x': -0.02572193,
#   'world_y': -0.10033012,
#   'world_z': 1.114501},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292467832565308,
#   'cls': 'squarenut',
#   'px_cam2': 59,
#   'py_cam2': 179,
#   'w_cam2': 50,
#   'h_cam2': 50,
#   'conf_cam2': 0.9108989834785461,
#   'ee_x': -0.023541648,
#   'ee_y': -0.05788925,
#   'ee_z': 1.1193202,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 16,
#   'w_cam1': 66,
#   'h_cam1': 32,
#   'conf_cam1': 0.9127501249313354,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 181,
#   'w_cam2': 131,
#   'h_cam2': 125,
#   'conf_cam2': 0.8649046421051025,
#   'ee_x': -0.023541648,
#   'ee_y': -0.05788925,
#   'ee_z': 1.1193202,
#   'world_x': -0.02102209,
#   'world_y': -0.0998939,
#   'world_z': 1.1144532},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292592406272888,
#   'cls': 'squarenut',
#   'px_cam2': 59,
#   'py_cam2': 180,
#   'w_cam2': 49,
#   'h_cam2': 47,
#   'conf_cam2': 0.9082319140434265,
#   'ee_x': -0.01925293,
#   'ee_y': -0.057529107,
#   'ee_z': 1.1192973,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 16,
#   'w_cam1': 66,
#   'h_cam1': 32,
#   'conf_cam1': 0.914260983467102,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 180,
#   'w_cam2': 130,
#   'h_cam2': 125,
#   'conf_cam2': 0.8631638884544373,
#   'ee_x': -0.01925293,
#   'ee_y': -0.057529107,
#   'ee_z': 1.1192973,
#   'world_x': -0.016742801,
#   'world_y': -0.099532716,
#   'world_z': 1.1144234},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292467832565308,
#   'cls': 'squarenut',
#   'px_cam2': 59,
#   'py_cam2': 182,
#   'w_cam2': 49,
#   'h_cam2': 48,
#   'conf_cam2': 0.9081103801727295,
#   'ee_x': -0.015174443,
#   'ee_y': -0.0571511,
#   'ee_z': 1.1195482,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 16,
#   'w_cam1': 67,
#   'h_cam1': 33,
#   'conf_cam1': 0.9188717603683472,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 181,
#   'w_cam2': 130,
#   'h_cam2': 125,
#   'conf_cam2': 0.8639926314353943,
#   'ee_x': -0.015174443,
#   'ee_y': -0.0571511,
#   'ee_z': 1.1195482,
#   'world_x': -0.012666862,
#   'world_y': -0.09915377,
#   'world_z': 1.1146656},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292265772819519,
#   'cls': 'squarenut',
#   'px_cam2': 59,
#   'py_cam2': 182,
#   'w_cam2': 49,
#   'h_cam2': 48,
#   'conf_cam2': 0.9049285650253296,
#   'ee_x': -0.011359233,
#   'ee_y': -0.056908265,
#   'ee_z': 1.1200603,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 16,
#   'w_cam1': 67,
#   'h_cam1': 33,
#   'conf_cam1': 0.9145727753639221,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 180,
#   'w_cam2': 130,
#   'h_cam2': 124,
#   'conf_cam2': 0.8664162755012512,
#   'ee_x': -0.011359233,
#   'ee_y': -0.056908265,
#   'ee_z': 1.1200603,
#   'world_x': -0.008857149,
#   'world_y': -0.09891026,
#   'world_z': 1.1151754},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292243123054504,
#   'cls': 'squarenut',
#   'px_cam2': 59,
#   'py_cam2': 183,
#   'w_cam2': 50,
#   'h_cam2': 47,
#   'conf_cam2': 0.8835741877555847,
#   'ee_x': -0.007701186,
#   'ee_y': -0.056750998,
#   'ee_z': 1.1206114,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 17,
#   'w_cam1': 67,
#   'h_cam1': 35,
#   'conf_cam1': 0.9133214354515076,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 181,
#   'w_cam2': 131,
#   'h_cam2': 124,
#   'conf_cam2': 0.8663551807403564,
#   'ee_x': -0.007701186,
#   'ee_y': -0.056750998,
#   'ee_z': 1.1206114,
#   'world_x': -0.005204413,
#   'world_y': -0.0987536,
#   'world_z': 1.1157252},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292132258415222,
#   'cls': 'squarenut',
#   'px_cam2': 58,
#   'py_cam2': 183,
#   'w_cam2': 51,
#   'h_cam2': 43,
#   'conf_cam2': 0.7708607912063599,
#   'ee_x': -0.004350474,
#   'ee_y': -0.05658078,
#   'ee_z': 1.1210454,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 18,
#   'w_cam1': 68,
#   'h_cam1': 36,
#   'conf_cam1': 0.9117810130119324,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 181,
#   'w_cam2': 131,
#   'h_cam2': 124,
#   'conf_cam2': 0.8657581806182861,
#   'ee_x': -0.004350474,
#   'ee_y': -0.05658078,
#   'ee_z': 1.1210454,
#   'world_x': -0.0018553862,
#   'world_y': -0.09858293,
#   'world_z': 1.1161536},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292099475860596,
#   'cls': 'squarenut',
#   'px_cam2': 59,
#   'py_cam2': 183,
#   'w_cam2': 49,
#   'h_cam2': 42,
#   'conf_cam2': 0.843339204788208,
#   'ee_x': -0.0010787903,
#   'ee_y': -0.05626698,
#   'ee_z': 1.1215112,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 18,
#   'w_cam1': 69,
#   'h_cam1': 36,
#   'conf_cam1': 0.9052128195762634,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 180,
#   'w_cam2': 130,
#   'h_cam2': 124,
#   'conf_cam2': 0.867328941822052,
#   'ee_x': -0.0010787903,
#   'ee_y': -0.05626698,
#   'ee_z': 1.1215112,
#   'world_x': 0.001423387,
#   'world_y': -0.09826768,
#   'world_z': 1.1166066},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9292031526565552,
#   'cls': 'squarenut',
#   'px_cam2': 59,
#   'py_cam2': 184,
#   'w_cam2': 46,
#   'h_cam2': 41,
#   'conf_cam2': 0.806759774684906,
#   'ee_x': 0.001882508,
#   'ee_y': -0.05577523,
#   'ee_z': 1.1220442,
#   'world_x': -0.1107713,
#   'world_y': 0.12041598,
#   'world_z': 0.82997894},
#  {'px_cam1': 68,
#   'py_cam1': 18,
#   'w_cam1': 69,
#   'h_cam1': 37,
#   'conf_cam1': 0.9073338508605957,
#   'cls': 'roundnut',
#   'px_cam2': 179,
#   'py_cam2': 181,
#   'w_cam2': 130,
#   'h_cam2': 124,
#   'conf_cam2': 0.8667757511138916,
#   'ee_x': 0.001882508,
#   'ee_y': -0.05577523,
#   'ee_z': 1.1220442,
#   'world_x': 0.004395324,
#   'world_y': -0.09777328,
#   'world_z': 1.1171193},
#  {'px_cam1': 171,
#   'py_cam1': 102,
#   'w_cam1': 52,
#   'h_cam1': 32,
#   'conf_cam1': 0.9298662543296814,
#   'cls': 'squarenut',
#   'px_cam2': 181,
#   'py_cam2': 177,
#   'w_cam2': 143,
#   'h_cam2': 129,
#   'conf_cam2': 0.8837398290634155,
#   'ee_x': -0.11286347,
#   'ee_y': 0.16495146,
#   'ee_z': 0.8375817,
#   'world_x': -0.109300025,
#   'world_y': 0.12328508,
#   'world_z': 0.83218586},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9267690181732178,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11286347,
#   'ee_y': 0.16495146,
#   'ee_z': 0.8375817,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 48,
#   'conf_cam1': 0.9272134900093079,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.113527276,
#   'ee_y': 0.16667935,
#   'ee_z': 0.8439245,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 172,
#   'py_cam1': 103,
#   'w_cam1': 52,
#   'h_cam1': 35,
#   'conf_cam1': 0.9242811799049377,
#   'cls': 'squarenut',
#   'px_cam2': 181,
#   'py_cam2': 177,
#   'w_cam2': 140,
#   'h_cam2': 129,
#   'conf_cam2': 0.876486599445343,
#   'ee_x': -0.113527276,
#   'ee_y': 0.16667935,
#   'ee_z': 0.8439245,
#   'world_x': -0.109644756,
#   'world_y': 0.12550153,
#   'world_z': 0.8383119},
#  {'px_cam1': 173,
#   'py_cam1': 102,
#   'w_cam1': 53,
#   'h_cam1': 37,
#   'conf_cam1': 0.9278953075408936,
#   'cls': 'squarenut',
#   'px_cam2': 179,
#   'py_cam2': 177,
#   'w_cam2': 141,
#   'h_cam2': 128,
#   'conf_cam2': 0.8670421838760376,
#   'ee_x': -0.113236964,
#   'ee_y': 0.16714002,
#   'ee_z': 0.8510851,
#   'world_x': -0.10912458,
#   'world_y': 0.12616557,
#   'world_z': 0.8454295},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9261214733123779,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.113236964,
#   'ee_y': 0.16714002,
#   'ee_z': 0.8510851,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9261645078659058,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.112635165,
#   'ee_y': 0.16772296,
#   'ee_z': 0.85839194,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 174,
#   'py_cam1': 99,
#   'w_cam1': 53,
#   'h_cam1': 37,
#   'conf_cam1': 0.9238497018814087,
#   'cls': 'squarenut',
#   'px_cam2': 178,
#   'py_cam2': 177,
#   'w_cam2': 142,
#   'h_cam2': 131,
#   'conf_cam2': 0.8644056916236877,
#   'ee_x': -0.112635165,
#   'ee_y': 0.16772296,
#   'ee_z': 0.85839194,
#   'world_x': -0.108348824,
#   'world_y': 0.1268543,
#   'world_z': 0.8526942},
#  {'px_cam1': 174,
#   'py_cam1': 98,
#   'w_cam1': 54,
#   'h_cam1': 36,
#   'conf_cam1': 0.9286049008369446,
#   'cls': 'squarenut',
#   'px_cam2': 178,
#   'py_cam2': 176,
#   'w_cam2': 142,
#   'h_cam2': 129,
#   'conf_cam2': 0.8648527264595032,
#   'ee_x': -0.11276822,
#   'ee_y': 0.16726801,
#   'ee_z': 0.8657025,
#   'world_x': -0.10837169,
#   'world_y': 0.12651852,
#   'world_z': 0.8600239},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9266613125801086,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11276822,
#   'ee_y': 0.16726801,
#   'ee_z': 0.8657025,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9266360998153687,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.1127211,
#   'ee_y': 0.16751204,
#   'ee_z': 0.8730961,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 174,
#   'py_cam1': 96,
#   'w_cam1': 54,
#   'h_cam1': 37,
#   'conf_cam1': 0.9242148399353027,
#   'cls': 'squarenut',
#   'px_cam2': 178,
#   'py_cam2': 177,
#   'w_cam2': 143,
#   'h_cam2': 129,
#   'conf_cam2': 0.8661883473396301,
#   'ee_x': -0.1127211,
#   'ee_y': 0.16751204,
#   'ee_z': 0.8730961,
#   'world_x': -0.10823124,
#   'world_y': 0.12690815,
#   'world_z': 0.86736757},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9262380003929138,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11283789,
#   'ee_y': 0.16814324,
#   'ee_z': 0.88062924,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 174,
#   'py_cam1': 94,
#   'w_cam1': 54,
#   'h_cam1': 37,
#   'conf_cam1': 0.9127376079559326,
#   'cls': 'squarenut',
#   'px_cam2': 178,
#   'py_cam2': 177,
#   'w_cam2': 142,
#   'h_cam2': 129,
#   'conf_cam2': 0.865278422832489,
#   'ee_x': -0.11283789,
#   'ee_y': 0.16814324,
#   'ee_z': 0.88062924,
#   'world_x': -0.10826895,
#   'world_y': 0.12760152,
#   'world_z': 0.87484366},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9263210892677307,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11361241,
#   'ee_y': 0.16808468,
#   'ee_z': 0.8883056,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 175,
#   'py_cam1': 91,
#   'w_cam1': 55,
#   'h_cam1': 38,
#   'conf_cam1': 0.8961266279220581,
#   'cls': 'squarenut',
#   'px_cam2': 178,
#   'py_cam2': 177,
#   'w_cam2': 140,
#   'h_cam2': 128,
#   'conf_cam2': 0.8693746328353882,
#   'ee_x': -0.11361241,
#   'ee_y': 0.16808468,
#   'ee_z': 0.8883056,
#   'world_x': -0.108990766,
#   'world_y': 0.12770134,
#   'world_z': 0.8824849},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.926293134689331,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.114984944,
#   'ee_y': 0.16833776,
#   'ee_z': 0.896039,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 175,
#   'py_cam1': 88,
#   'w_cam1': 55,
#   'h_cam1': 35,
#   'conf_cam1': 0.9189926385879517,
#   'cls': 'squarenut',
#   'px_cam2': 179,
#   'py_cam2': 178,
#   'w_cam2': 142,
#   'h_cam2': 131,
#   'conf_cam2': 0.8652704358100891,
#   'ee_x': -0.114984944,
#   'ee_y': 0.16833776,
#   'ee_z': 0.896039,
#   'world_x': -0.11029201,
#   'world_y': 0.12806664,
#   'world_z': 0.8901749},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9265398383140564,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.115431026,
#   'ee_y': 0.16834994,
#   'ee_z': 0.90375566,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 176,
#   'py_cam1': 85,
#   'w_cam1': 56,
#   'h_cam1': 36,
#   'conf_cam1': 0.9202330708503723,
#   'cls': 'squarenut',
#   'px_cam2': 179,
#   'py_cam2': 178,
#   'w_cam2': 142,
#   'h_cam2': 131,
#   'conf_cam2': 0.8680080771446228,
#   'ee_x': -0.115431026,
#   'ee_y': 0.16834994,
#   'ee_z': 0.90375566,
#   'world_x': -0.11068303,
#   'world_y': 0.12817097,
#   'world_z': 0.8978598},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9265592694282532,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11547724,
#   'ee_y': 0.16846621,
#   'ee_z': 0.91135937,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 176,
#   'py_cam1': 82,
#   'w_cam1': 56,
#   'h_cam1': 35,
#   'conf_cam1': 0.918357789516449,
#   'cls': 'squarenut',
#   'px_cam2': 179,
#   'py_cam2': 178,
#   'w_cam2': 140,
#   'h_cam2': 130,
#   'conf_cam2': 0.869612991809845,
#   'ee_x': -0.11547724,
#   'ee_y': 0.16846621,
#   'ee_z': 0.91135937,
#   'world_x': -0.11069472,
#   'world_y': 0.12837178,
#   'world_z': 0.90540916},
#  {'px_cam1': 87,
#   'py_cam1': 145,
#   'w_cam1': 62,
#   'h_cam1': 49,
#   'conf_cam1': 0.9264788031578064,
#   'cls': 'roundnut',
#   'px_cam2': 0,
#   'py_cam2': 0,
#   'w_cam2': 0,
#   'h_cam2': 0,
#   'conf_cam2': 0,
#   'ee_x': -0.11582414,
#   'ee_y': 0.16858453,
#   'ee_z': 0.9189559,
#   'world_x': 0.03515354,
#   'world_y': -0.09963941,
#   'world_z': 0.8299885},
#  {'px_cam1': 176,
#   'py_cam1': 79,
#   'w_cam1': 57,
#   'h_cam1': 35,
#   'conf_cam1': 0.9204491376876831,
#   'cls': 'squarenut',
#   'px_cam2': 179,
#   'py_cam2': 178,
#   'w_cam2': 140,
#   'h_cam2': 130,
#   'conf_cam2': 0.8721689581871033,
#   'ee_x': -0.11582414,
#   'ee_y': 0.16858453,
#   'ee_z': 0.9189559,
#   'world_x': -0.11097403,
#   'world_y': 0.1286128,
#   'world_z': 0.91294885},
#  ...]

# %%
df = pd.DataFrame(df_list)
print(df.head(5))
print(len(df))
#reverse the dict
inv_class_dict = {v: k for k, v in yolo_model.names.items()}
print(inv_class_dict)
# Replace cls names with the cls id from the yolo model
df['cls_id'] = df['cls'].map(inv_class_dict)
df.head(5)
print(len(df))
# Out:
#    px_cam1  py_cam1  w_cam1  h_cam1  conf_cam1        cls  px_cam2  py_cam2  \
# 0       84      100      47      39   0.920213   roundnut      181      181
# 1      179      103      56      34   0.915864  squarenut        0        0
# 2      179      103      56      34   0.915954  squarenut        0        0
# 3       84       99      46      39   0.910254   roundnut      181      182
# 4      179      103      56      34   0.916120  squarenut        0        0
#
#    w_cam2  h_cam2  conf_cam2      ee_x      ee_y      ee_z   world_x  \
# 0     139     136   0.889288 -0.119544 -0.070190  0.837325 -0.115339
# 1       0       0   0.000000 -0.119544 -0.070190  0.837325 -0.111504
# 2       0       0   0.000000 -0.119422 -0.070797  0.843927 -0.111504
# 3     140     137   0.891662 -0.119422 -0.070797  0.843927 -0.115579
# 4       0       0   0.000000 -0.118543 -0.071590  0.851193 -0.111504
#
#     world_y   world_z
# 0 -0.112498  0.833131
# 1  0.144208  0.829979
# 2  0.144208  0.829979
# 3 -0.113237  0.839734
# 4  0.144208  0.829979
# 14345
# {'round_nut': 0, 'square_nut': 1}
# 14345

# %%
from sklearn.ensemble import GradientBoostingRegressor
X_dual = df[["cls_id", "px_cam1", "py_cam1", "w_cam1", "h_cam1", "conf_cam1", "px_cam2", "py_cam2", "w_cam2", "h_cam2", "conf_cam2", "ee_x", "ee_y", "ee_z"]].values
Y_dual = df[["world_x", "world_y", "world_z"]].values

reg_x_dual = GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.1)
reg_y_dual = GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.1)
reg_z_dual = GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.1)

reg_x_dual.fit(X_dual, Y_dual[:, 0])
reg_y_dual.fit(X_dual, Y_dual[:, 1])
reg_z_dual.fit(X_dual, Y_dual[:, 2])
def pixel_to_world_dual(cls, px1, py1, w1, h1, conf1, px2, py2, w2, h2, conf2, ee_x, ee_y, ee_z):
    features = np.array([[cls, px1, py1, w1, h1, conf1, px2, py2, w2, h2, conf2, ee_x, ee_y, ee_z]])
    x = reg_x_dual.predict(features)[0]
    y = reg_y_dual.predict(features)[0]
    z = reg_z_dual.predict(features)[0]
    return x, y, z
# --- Example usage ---
# Get a prediction for the first row of the df dataframe
cls = df.iloc[0]["cls_id"]
px1, py1, w1, h1, conf1 = df.iloc[0][["px_cam1", "py_cam1", "w_cam1", "h_cam1", "conf_cam1"]]
px2, py2, w2, h2, conf2 = df.iloc[0][["px_cam2", "py_cam2", "w_cam2", "h_cam2", "conf_cam2"]]
ee_x, ee_y, ee_z = df.iloc[0][["ee_x", "ee_y", "ee_z"]]
print(pixel_to_world_dual(cls, px1, py1, w1, h1, conf1, px2, py2, w2, h2, conf2, ee_x, ee_y, ee_z))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 9
#       6 reg_y_dual = GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.1)
#       7 reg_z_dual = GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.1)
# ----> 9 reg_x_dual.fit(X_dual, Y_dual[:, 0])
#      10 reg_y_dual.fit(X_dual, Y_dual[:, 1])
#      11 reg_z_dual.fit(X_dual, Y_dual[:, 2])
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:416, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     410     self._clear_state()
#     412 # Check input
#     413 # Since check_array converts both X and y to the same dtype, but the
#     414 # trees use different types for X and y, checking them separately.
# --> 416 X, y = self._validate_data(
#     417     X, y, accept_sparse=["csr", "csc", "coo"], dtype=DTYPE, multi_output=True
#     418 )
#     420 sample_weight_is_none = sample_weight is None
#     422 sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1146, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1141         estimator_name = _check_estimator_name(estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
# -> 1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    1149     accept_large_sparse=accept_large_sparse,
#    1150     dtype=dtype,
#    1151     order=order,
#    1152     copy=copy,
#    1153     force_all_finite=force_all_finite,
#    1154     ensure_2d=ensure_2d,
#    1155     allow_nd=allow_nd,
#    1156     ensure_min_samples=ensure_min_samples,
#    1157     ensure_min_features=ensure_min_features,
#    1158     estimator=estimator,
#    1159     input_name="X",
#    1160 )
#    1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:957, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     951         raise ValueError(
#     952             "Found array with dim %d. %s expected <= 2."
#     953             % (array.ndim, estimator_name)
#     954         )
#     956     if force_all_finite:
# --> 957         _assert_all_finite(
#     958             array,
#     959             input_name=input_name,
#     960             estimator_name=estimator_name,
#     961             allow_nan=force_all_finite == "allow-nan",
#     962         )
#     964 if ensure_min_samples > 0:
#     965     n_samples = _num_samples(array)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:122, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     119 if first_pass_isfinite:
#     120     return
# --> 122 _assert_all_finite_element_wise(
#     123     X,
#     124     xp=xp,
#     125     allow_nan=allow_nan,
#     126     msg_dtype=msg_dtype,
#     127     estimator_name=estimator_name,
#     128     input_name=input_name,
#     129 )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:171, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     154 if estimator_name and input_name == "X" and has_nan_error:
#     155     # Improve the error message on how to handle missing values in
#     156     # scikit-learn.
#     157     msg_err += (
#     158         f"\n{estimator_name} does not accept missing values"
#     159         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     169         "#estimators-that-handle-nan-values"
#     170     )
# --> 171 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# GradientBoostingRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
# Replace pred columns with the dual cam predictions
df["pred_x"] = df.apply(lambda row: pixel_to_world_dual(row["cls_id"], row["px_cam1"], row["py_cam1"], row["w_cam1"], row["h_cam1"], row["conf_cam1"], row["px_cam2"], row["py_cam2"], row["w_cam2"], row["h_cam2"], row["conf_cam2"], row["ee_x"], row["ee_y"], row["ee_z"])[0], axis=1)
df["pred_y"] = df.apply(lambda row: pixel_to_world_dual(row["cls_id"], row["px_cam1"], row["py_cam1"], row["w_cam1"], row["h_cam1"], row["conf_cam1"], row["px_cam2"], row["py_cam2"], row["w_cam2"], row["h_cam2"], row["conf_cam2"], row["ee_x"], row["ee_y"], row["ee_z"])[1], axis=1)
df["pred_z"] = df.apply(lambda row: pixel_to_world_dual(row["cls_id"], row["px_cam1"], row["py_cam1"], row["w_cam1"], row["h_cam1"], row["conf_cam1"], row["px_cam2"], row["py_cam2"], row["w_cam2"], row["h_cam2"], row["conf_cam2"], row["ee_x"], row["ee_y"], row["ee_z"])[2], axis=1)

# Compute the differences between the world and predicted positions
df["diff_x"] = df["world_x"] - df["pred_x"]
df["diff_y"] = df["world_y"] - df["pred_y"]
df["diff_z"] = df["world_z"] - df["pred_z"]

# Compute the error metrics
mean_error_x = df["diff_x"].mean()
mean_error_y = df["diff_y"].mean()
mean_error_z = df["diff_z"].mean()
std_error_x = df["diff_x"].std()
std_error_y = df["diff_y"].std()
std_error_z = df["diff_z"].std()
print(f"Mean Error X: {mean_error_x}, Std Error X: {std_error_x}")
print(f"Mean Error Y: {mean_error_y}, Std Error Y: {std_error_y}")
print(f"Mean Error Z: {mean_error_z}, Std Error Z: {std_error_z}")
# Out:
# Mean Error X: 1.9395442388404577e-18, Std Error X: 0.0001581006049551298
# Mean Error Y: -2.1788260255780467e-18, Std Error Y: 0.00023408488149310455
# Mean Error Z: 1.3428682851521838e-17, Std Error Z: 0.0021298690581121014

# %%
# Save the dual cam models
joblib.dump({"reg_x": reg_x_dual, "reg_y": reg_y_dual, "reg_z": reg_z_dual}, "nutassembly_dual_cam_calibration_models.pkl")
# Out:
# ['nutassembly_dual_cam_calibration_models.pkl']
